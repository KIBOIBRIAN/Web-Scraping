# %% [markdown]
# # Yellow pages

# %% [markdown]
# ## Import libraries

# %%
import requests
from lxml import html
import unicodecsv as csv
import argparse
import datetime
import pandas as pd
from collections import OrderedDict, deque
import re

# %% [markdown]
# ## Define parameters function
#
# - Function to set parameters for search on yellow pages. Set parameter to True to include in search. Must haveat least one true for each parameter

# %%
def parameters():
	keyword_dict = {
		'Dentists': True
	}

	city_province_dict = {
		'toronto+ON': True
	}

	pagination_list=[*range(1,5)]
	
	if sum(keyword_dict.values()) == 0 or sum(city_province_dict.values()) == 0:
		sys.exit("Ensure you have specified at least one keyword and city, province")
	else:
		return keyword_dict, city_province_dict, pagination_list

# %% [markdown]
# ## Define crawl function
#
# Function to process yellowpage listing page
# - param keyword: search query
# - param place_city : place city name
# - param place_province: place province name

# %%
pagination='3'
keyword='Dentists'
place_city_province='toronto+ON'
# url = "https://www.yellowpages.ca/search/si/3/{0}/{1}".format(keyword, place_city_province )
url = "https://www.yellowpages.ca/search/si/3/Restaurants/Toronto+ON"
	# /pagenumber/keyword/placecity+placeprovince

print("retrieving ",url)

headers = {'Accept':'text/html,application/xhtml+xml,application/xml;q=0.9,image/webp,image/apng,*/*;q=0.8',
			'Accept-Encoding':'gzip, deflate, br',
			'Accept-Language':'en-GB,en;q=0.9,en-US;q=0.8,ml;q=0.7',
			'Cache-Control':'max-age=0',
			'Connection':'keep-alive',
			'Host':'www.yellowpages.ca',
			'Upgrade-Insecure-Requests':'1',
			'User-Agent':'Mozilla/5.0 (X11; Linux x86_64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/64.0.3282.140 Safari/537.36'
		}

# Adding retries
for retry in range(2):
	try:
		response = requests.get(url,verify=False, headers = headers )

		if response.status_code==200:
			parser = html.fromstring(response.text)

			#making links absolute
			base_url = "https://www.yellowpages.ca"
			parser.make_links_absolute(base_url)

			XPATH_LISTINGS = "//div[contains(@class, 'listing listing--bottomcta placement')]" #listings
			listings = parser.xpath(XPATH_LISTINGS)
			scraped_results = []

			for results in listings:

				XPATH_BUSINESS_NAME = ".//a[contains(@class, 'listing__name--link')]//text()"
				# XPATH_BUSINESS_PAGE = ".//a[contains(@class, 'listing__name--link')]//@href"
				XPATH_STREET = ".//div[contains(@class, 'listing__address')]//span[@itemprop='address']//span[@itemprop='streetAddress']//text()"
				XPATH_LOCALITY = ".//div[contains(@class, 'listing__address')]//span[@itemprop='address']//span[@itemprop='addressLocality']//text()"
				XPATH_REGION = ".//div[contains(@class, 'listing__address')]//span[@itemprop='address']//span[@itemprop='addressRegion']//text()"
				XPATH_ZIP_CODE = ".//div[contains(@class, 'listing__address')]//span[@itemprop='address']//span[@itemprop='postalCode']//text()"
				XPATH_WEBSITE = ".//div[contains(@class, 'listing__mlr__root')]//ul//li[3]//a//@href"
				
				XPATH_PHONE= ".//div[contains(@class, 'listing__mlr__root')]//ul//li[1]//a//@data-phone"
				XPATH_DESCRIPTION = ".//article[contains(@class, 'listing__details__teaser')]//text()"
				XPATH_PRODUCTS = ".//div[contains(@class, 'listing__captext')]//text()"


				raw_business_name = results.xpath(XPATH_BUSINESS_NAME)
				# raw_business_page = results.xpath(XPATH_BUSINESS_PAGE)
				raw_website = results.xpath(XPATH_WEBSITE)
				raw_street = results.xpath(XPATH_STREET)
				raw_locality = results.xpath(XPATH_LOCALITY)
				raw_region = results.xpath(XPATH_REGION)
				raw_zip_code = results.xpath(XPATH_ZIP_CODE)

				raw_phone=results.xpath(XPATH_PHONE)
				raw_products=results.xpath(XPATH_PRODUCTS)
				raw_description=results.xpath(XPATH_DESCRIPTION)
				
				business_name = ''.join(raw_business_name).strip() if raw_business_name else None
				# business_page = ''.join(raw_business_page).strip() if raw_business_page else None
				street = ''.join(raw_street).strip() if raw_street else None
				website = ''.join(raw_website).strip() if raw_website else None
				locality = ''.join(raw_locality).replace(',\xa0','').strip() if raw_locality else None
				region = ''.join(raw_region).strip() if raw_region else None
				zipcode = ''.join(raw_zip_code).strip() if raw_zip_code else None

				phone= ''.join(raw_phone).strip() if raw_phone else None
				product=''.join(raw_products).strip() if raw_products else None
				description=''.join(raw_description).strip() if raw_description else None

				business_details = {
									'business_name':business_name,
									# 'business_page':business_page,
									'street': street,
									'website':website,
									'street':street,
									'city':locality,
									'region':region,
									'zipcode':zipcode,
									'industry': keyword,
									'phone': phone,
									'product':product,
									'description':description,
									# 'updated_at': datetime.datetime.now()
				}
				scraped_results.append(business_details)

		

		elif response.status_code==404:
			print("Could not find a location matching")
			#no need to retry for non existing page
			break
		else:
			print("Failed to process page")
		
	except:
		print("Failed to process page")
# Out:
# retrieving  https://www.yellowpages.ca/search/si/5/Restaurants/toronto+ON
# c:\Users\User\anaconda3\lib\site-packages\urllib3\connectionpool.py:1043: InsecureRequestWarning: Unverified HTTPS request is being made to host 'www.yellowpages.ca'. Adding certificate verification is strongly advised. See: https://urllib3.readthedocs.io/en/1.26.x/advanced-usage.html#ssl-warnings
#   warnings.warn(
# c:\Users\User\anaconda3\lib\site-packages\urllib3\connectionpool.py:1043: InsecureRequestWarning: Unverified HTTPS request is being made to host 'www.yellowpages.ca'. Adding certificate verification is strongly advised. See: https://urllib3.readthedocs.io/en/1.26.x/advanced-usage.html#ssl-warnings
#   warnings.warn(
# c:\Users\User\anaconda3\lib\site-packages\urllib3\connectionpool.py:1043: InsecureRequestWarning: Unverified HTTPS request is being made to host 'www.yellowpages.ca'. Adding certificate verification is strongly advised. See: https://urllib3.readthedocs.io/en/1.26.x/advanced-usage.html#ssl-warnings
#   warnings.warn(
# c:\Users\User\anaconda3\lib\site-packages\urllib3\connectionpool.py:1043: InsecureRequestWarning: Unverified HTTPS request is being made to host 'www.yellowpages.ca'. Adding certificate verification is strongly advised. See: https://urllib3.readthedocs.io/en/1.26.x/advanced-usage.html#ssl-warnings
#   warnings.warn(

# %%
scraped_results
# Out:
# [{'business_name': "Bardi's Steak House",
#   'street': '56 York St',
#   'website': 'https://www.yellowpages.ca/gourl/079b5b9f8c61d6de97e5fd1f0e5b66b35adc1c27?redirect=http%3A%2F%2Fwww.bardis.com%2F',
#   'city': 'Toronto',
#   'region': 'ON',
#   'zipcode': 'M5J 1S8',
#   'industry': 'Dentists',
#   'phone': '647-849-3080',
#   'product': 'Extensive Wine List, Restaurant With Party Services, Restaurant With Private Rooms',
#   'description': 'Since 1966, Exceptional Dining, Certified Angus Beef, Wine Spectator Award of Excellence, Steps from Skydome, Air Canada Centre, Convention Centre\nmore...\nSee more text'},
#  {'business_name': 'Astoria Shish Kebob House Inc',
#   'street': '390 Danforth Ave',
#   'website': 'https://www.yellowpages.ca/gourl/503cbea0b629dc585b032529db295f94212dcab8?redirect=http%3A%2F%2Fwww.astoriashishkebobhouse.com%2F',
#   'city': 'Toronto',
#   'region': 'ON',
#   'zipcode': 'M4K 1P3',
#   'industry': 'Dentists',
#   'phone': '647-846-7210',
#   'product': 'Casual Dining, Greek, Mediterranean, Take-out, Online Menu, Reservation, Alcohol Served, Wheelchair-accessible Restaurant, Group Reservation',
#   'description': "For over 40 years, this venerable 'institution of higher dining' has come to symbolize the culinary qualities the Danforth is known for: great food, great quality, and great value\nmore...\nSee more text"},
#  {'business_name': 'Kalyvia Restaurant',
#   'street': '420 Danforth Ave',
#   'website': 'https://www.yellowpages.ca/gourl/7b2a1b15fa536ade8d1445861ed75fd509e1f8bd?redirect=http%3A%2F%2Fwww.kalyvia.com%2F',
#   'city': 'Toronto',
#   'region': 'ON',
#   'zipcode': 'M4K 1P3',
#   'industry': 'Dentists',
#   'phone': '416-463-3333',
#   'product': 'Mediterranean, Greek, Alcohol Served, Group Reservation, Restaurant With Catering Services, Restaurant With Delivery Services, Take-out',
#   'description': 'CELEBRATING MORE THAN 20 YEARS OF SUCCESS SERVING AUTHENIC GREEK MEALS ON THE DANFORTH\nmore...\nSee more text'},
#  {'business_name': 'Dim Sum King',
#   'street': '421 Dundas St W',
#   'website': 'https://www.yellowpages.ca/merchant/directions/7730741/?what=Restaurants&where=Toronto+ON&useContext=true',
#   'city': 'Toronto',
#   'region': 'ON',
#   'zipcode': 'M5T 2W4',
#   'industry': 'Dentists',
#   'phone': '647-360-4006',
#   'product': 'Crispy Chicken, Fried Crab, BBQ, Soups, Seafood, Poultry, Szechuan Style, Cantonese, Take-out',
#   'description': 'Small bite size traditional breakfast foods prepared to perfection at Dim Sum King in Toronto is what keeps the masses flocking.'},
#  {'business_name': 'The Big Carrot Beach Community Market',
#   'street': '125 Southwood Dr',
#   'website': 'https://www.yellowpages.ca/gourl/a56be2c9b3173ca83e48e8e6aed0ec0b2f1fcd87?redirect=https%3A%2F%2Fthebigcarrot.ca%2F',
#   'city': 'Toronto',
#   'region': 'ON',
#   'zipcode': 'M4E 0B8',
#   'industry': 'Dentists',
#   'phone': '416-466-2129',
#   'product': 'The Beaches',
#   'description': 'The Big Carrot is a worker-owned natural food market that has been committed to local, organic, non-GMO and sustainable food systems since 1983.\nmore...\nSee more text'},
#  {'business_name': 'The Big Carrot Danforth Community Market',
#   'street': '348 Danforth Ave',
#   'website': 'https://www.yellowpages.ca/gourl/a56be2c9b3173ca83e48e8e6aed0ec0b2f1fcd87?redirect=https%3A%2F%2Fthebigcarrot.ca%2F',
#   'city': 'Toronto',
#   'region': 'ON',
#   'zipcode': 'M4K 1N8',
#   'industry': 'Dentists',
#   'phone': '416-466-2129',
#   'product': None,
#   'description': 'The Big Carrot is a worker-owned natural food market that has been committed to local, organic, non-GMO and sustainable food systems since 1983.\nmore...\nSee more text'}]

# %%
def parse_listing(keyword, place_city_province, pagination=3):
    	
	url = "https://www.yellowpages.ca/search/si/{0}/{1}/{2}".format(pagination,keyword, place_city_province )
	# url = "https://www.yellowpages.ca/search/si/{pagination}/{keyword}/{place_city_province}"
	# /pagenumber/keyword/placecity+placeprovince

	print("retrieving ",url)

	headers = {'Accept':'text/html,application/xhtml+xml,application/xml;q=0.9,image/webp,image/apng,*/*;q=0.8',
				'Accept-Encoding':'gzip, deflate, br',
				'Accept-Language':'en-GB,en;q=0.9,en-US;q=0.8,ml;q=0.7',
				'Cache-Control':'max-age=0',
				'Connection':'keep-alive',
				'Host':'www.yellowpages.ca',
				'Upgrade-Insecure-Requests':'1',
				'User-Agent':'Mozilla/5.0 (X11; Linux x86_64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/64.0.3282.140 Safari/537.36'
			}

	# Adding retries
	for retry in range(10):
		try:
			response = requests.get(url,verify=False, headers = headers )

			if response.status_code==200:
				parser = html.fromstring(response.text)

				#making links absolute
				base_url = "https://www.yellowpages.ca"
				parser.make_links_absolute(base_url)

				XPATH_LISTINGS = "//div[contains(@class, 'listing listing--bottomcta placement')]" #listings
				listings = parser.xpath(XPATH_LISTINGS)
				scraped_results = []

				for results in listings:

					XPATH_BUSINESS_NAME = ".//a[contains(@class, 'listing__name--link')]//text()"
					# XPATH_BUSINESS_PAGE = ".//a[contains(@class, 'listing__name--link')]//@href"
					XPATH_STREET = ".//div[contains(@class, 'listing__address')]//span[@itemprop='address']//span[@itemprop='streetAddress']//text()"
					XPATH_LOCALITY = ".//div[contains(@class, 'listing__address')]//span[@itemprop='address']//span[@itemprop='addressLocality']//text()"
					XPATH_REGION = ".//div[contains(@class, 'listing__address')]//span[@itemprop='address']//span[@itemprop='addressRegion']//text()"
					XPATH_ZIP_CODE = ".//div[contains(@class, 'listing__address')]//span[@itemprop='address']//span[@itemprop='postalCode']//text()"
					XPATH_WEBSITE = ".//div[contains(@class, 'listing__mlr__root')]//ul//li[3]//a//@href"
					
					XPATH_PHONE= ".//div[contains(@class, 'listing__mlr__root')]//ul//li[1]//a//@data-phone"
					XPATH_DESCRIPTION = ".//article[contains(@class, 'listing__details__teaser')]//text()"
					XPATH_PRODUCTS = ".//div[contains(@class, 'listing__captext')]//text()"


					raw_business_name = results.xpath(XPATH_BUSINESS_NAME)
					# raw_business_page = results.xpath(XPATH_BUSINESS_PAGE)
					raw_website = results.xpath(XPATH_WEBSITE)
					raw_street = results.xpath(XPATH_STREET)
					raw_locality = results.xpath(XPATH_LOCALITY)
					raw_region = results.xpath(XPATH_REGION)
					raw_zip_code = results.xpath(XPATH_ZIP_CODE)

					raw_phone=results.xpath(XPATH_PHONE)
					raw_products=results.xpath(XPATH_PRODUCTS)
					raw_description=results.xpath(XPATH_DESCRIPTION)
					
					business_name = ''.join(raw_business_name).strip() if raw_business_name else None
					# business_page = ''.join(raw_business_page).strip() if raw_business_page else None
					street = ''.join(raw_street).strip() if raw_street else None
					website = ''.join(raw_website).strip() if raw_website else None
					locality = ''.join(raw_locality).replace(',\xa0','').strip() if raw_locality else None
					region = ''.join(raw_region).strip() if raw_region else None
					zipcode = ''.join(raw_zip_code).strip() if raw_zip_code else None

					phone= ''.join(raw_phone).strip() if raw_phone else None
					product=''.join(raw_products).strip() if raw_products else None
					description=''.join(raw_description).strip() if raw_description else None

					business_details = {
										'business_name':business_name,
										# 'business_page':business_page,
										'street': street,
										'website':website,
										'street':street,
										'city':locality,
										'region':region,
										'zipcode':zipcode,
										'industry': keyword,
										'phone': phone,
										'product':product,
										'description':description,
										# 'updated_at': datetime.datetime.now()
					}
					scraped_results.append(business_details)

				return scraped_results

			elif response.status_code==404:
				print("Could not find a location matching")
				#no need to retry for non existing page
				break
			else:
				print("Failed to process page")
				return []
				
		except:
			print("Failed to process page")
			return []

# %%
pagination_list=[*range(1,5)]
for pagination in range(1,len(pagination_list)):
    print(pagination)
# Out:
# 1
# 2
# 3

# %%
pagination_list=[*range(1,5)]
for pagination in range(1,len(pagination_list)):
    print(pagination)
    scraped_data1=parse_listing('Dentists','toronto+ON',pagination)
# Out:
# 1
# retrieving  https://www.yellowpages.ca/search/si/1/Dentists/toronto+ON
# c:\Users\User\anaconda3\lib\site-packages\urllib3\connectionpool.py:1043: InsecureRequestWarning: Unverified HTTPS request is being made to host 'www.yellowpages.ca'. Adding certificate verification is strongly advised. See: https://urllib3.readthedocs.io/en/1.26.x/advanced-usage.html#ssl-warnings
#   warnings.warn(
# c:\Users\User\anaconda3\lib\site-packages\urllib3\connectionpool.py:1043: InsecureRequestWarning: Unverified HTTPS request is being made to host 'www.yellowpages.ca'. Adding certificate verification is strongly advised. See: https://urllib3.readthedocs.io/en/1.26.x/advanced-usage.html#ssl-warnings
#   warnings.warn(
# 2
# retrieving  https://www.yellowpages.ca/search/si/2/Dentists/toronto+ON
# c:\Users\User\anaconda3\lib\site-packages\urllib3\connectionpool.py:1043: InsecureRequestWarning: Unverified HTTPS request is being made to host 'www.yellowpages.ca'. Adding certificate verification is strongly advised. See: https://urllib3.readthedocs.io/en/1.26.x/advanced-usage.html#ssl-warnings
#   warnings.warn(
# c:\Users\User\anaconda3\lib\site-packages\urllib3\connectionpool.py:1043: InsecureRequestWarning: Unverified HTTPS request is being made to host 'www.yellowpages.ca'. Adding certificate verification is strongly advised. See: https://urllib3.readthedocs.io/en/1.26.x/advanced-usage.html#ssl-warnings
#   warnings.warn(
# 3
# retrieving  https://www.yellowpages.ca/search/si/3/Dentists/toronto+ON
# c:\Users\User\anaconda3\lib\site-packages\urllib3\connectionpool.py:1043: InsecureRequestWarning: Unverified HTTPS request is being made to host 'www.yellowpages.ca'. Adding certificate verification is strongly advised. See: https://urllib3.readthedocs.io/en/1.26.x/advanced-usage.html#ssl-warnings
#   warnings.warn(
# c:\Users\User\anaconda3\lib\site-packages\urllib3\connectionpool.py:1043: InsecureRequestWarning: Unverified HTTPS request is being made to host 'www.yellowpages.ca'. Adding certificate verification is strongly advised. See: https://urllib3.readthedocs.io/en/1.26.x/advanced-usage.html#ssl-warnings
#   warnings.warn(

# %%
scraped_data1=parse_listing('Dentists','toronto+ON',1)
# Out:
# retrieving  https://www.yellowpages.ca/search/si/1/Dentists/toronto+ON
# c:\Users\User\anaconda3\lib\site-packages\urllib3\connectionpool.py:1043: InsecureRequestWarning: Unverified HTTPS request is being made to host 'www.yellowpages.ca'. Adding certificate verification is strongly advised. See: https://urllib3.readthedocs.io/en/1.26.x/advanced-usage.html#ssl-warnings
#   warnings.warn(
# c:\Users\User\anaconda3\lib\site-packages\urllib3\connectionpool.py:1043: InsecureRequestWarning: Unverified HTTPS request is being made to host 'www.yellowpages.ca'. Adding certificate verification is strongly advised. See: https://urllib3.readthedocs.io/en/1.26.x/advanced-usage.html#ssl-warnings
#   warnings.warn(

# %%
scraped_data2=parse_listing('Dentists','toronto+ON',2)
# Out:
# retrieving  https://www.yellowpages.ca/search/si/2/Dentists/toronto+ON
# c:\Users\User\anaconda3\lib\site-packages\urllib3\connectionpool.py:1043: InsecureRequestWarning: Unverified HTTPS request is being made to host 'www.yellowpages.ca'. Adding certificate verification is strongly advised. See: https://urllib3.readthedocs.io/en/1.26.x/advanced-usage.html#ssl-warnings
#   warnings.warn(
# c:\Users\User\anaconda3\lib\site-packages\urllib3\connectionpool.py:1043: InsecureRequestWarning: Unverified HTTPS request is being made to host 'www.yellowpages.ca'. Adding certificate verification is strongly advised. See: https://urllib3.readthedocs.io/en/1.26.x/advanced-usage.html#ssl-warnings
#   warnings.warn(

# %%
pagination_list=[*range(1,5)]
pd.DataFrame(parse_listing('Dentists','toronto+ON',pagination_list=pagination_list)).shape
# Out:
# retrieving  https://www.yellowpages.ca/search/si/1/Dentists/toronto+ON
# c:\Users\User\anaconda3\lib\site-packages\urllib3\connectionpool.py:1043: InsecureRequestWarning: Unverified HTTPS request is being made to host 'www.yellowpages.ca'. Adding certificate verification is strongly advised. See: https://urllib3.readthedocs.io/en/1.26.x/advanced-usage.html#ssl-warnings
#   warnings.warn(
# c:\Users\User\anaconda3\lib\site-packages\urllib3\connectionpool.py:1043: InsecureRequestWarning: Unverified HTTPS request is being made to host 'www.yellowpages.ca'. Adding certificate verification is strongly advised. See: https://urllib3.readthedocs.io/en/1.26.x/advanced-usage.html#ssl-warnings
#   warnings.warn(
# (29, 10)

# %%
data.shape
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# c:\Users\User\Desktop\Projects\Web scraping\Yellowpage original\yellowpages-canada-scraper\yellowpages.ipynb Cell 13' in <cell line: 1>()
# ----> <a href='vscode-notebook-cell:/c%3A/Users/User/Desktop/Projects/Web%20scraping/Yellowpage%20original/yellowpages-canada-scraper/yellowpages.ipynb#ch0000030?line=0'>1</a> data.shape
#
# AttributeError: 'list' object has no attribute 'shape'

# %%
pd.DataFrame(scraped_data2).head()
# Out:
#                 business_name                street  \
# 0           City Oasis Dental      82 Adelaide St E
# 1  AIMS Dentistry at Sheppard   2048 Sheppard Ave E
# 2        Eglinton West Dental   1114 Eglinton Ave W
# 3          Pape Dental Centre          759 Pape Ave
# 4            Strugurescu M Dr  309-745 Danforth Ave
#
#                                              website        city region  \
# 0  https://www.yellowpages.ca/gourl/5757443dc0e03...     Toronto     ON
# 1  https://www.yellowpages.ca/gourl/eaeece855862c...  North York     ON
# 2  https://www.yellowpages.ca/gourl/63000c37de3cc...     Toronto     ON
# 3  https://www.yellowpages.ca/gourl/83db23f52f495...     Toronto     ON
# 4  https://www.yellowpages.ca/gourl/8d2066c2cd9b7...     Toronto     ON
#
#    zipcode  industry         phone  \
# 0  M5C 1K9  Dentists  647-342-4868
# 1  M2J 5B3  Dentists  647-846-2317
# 2  M6C 2E2  Dentists  647-484-2557
# 3  M4K 3T2  Dentists  647-558-2829
# 4  M4J 1L4  Dentists  416-687-2899
#
#                                              product  \
# 0                  General Dentist, Cosmetic Dentist
# 1                                               None
# 2                                               None
# 3  Halkiotis Jane Dr, General Dental Practice, Ge...
# 4                                    General Dentist
#
#                                          description
# 0  City Oasis Dental strives to provide the highe...
# 1                                            Dentist
# 2  Beautiful smiles are made here ! We offer prev...
# 3  Family And Cosmetic Dentistry Serving Toronto ...
# 4  Dr. Michael Strugurescu focuses on aiding and ...

# %%
pagination_list=[*range(1,5)]
data=[]
for i in range(len(pagination_list)):
    scraped_data=parse_listing('Dentists','toronto+ON',pagination_list[i])
    data.append(scraped_data)
data
# Out:
# retrieving  https://www.yellowpages.ca/search/si/1/Dentists/toronto+ON
# c:\Users\User\anaconda3\lib\site-packages\urllib3\connectionpool.py:1043: InsecureRequestWarning: Unverified HTTPS request is being made to host 'www.yellowpages.ca'. Adding certificate verification is strongly advised. See: https://urllib3.readthedocs.io/en/1.26.x/advanced-usage.html#ssl-warnings
#   warnings.warn(
# c:\Users\User\anaconda3\lib\site-packages\urllib3\connectionpool.py:1043: InsecureRequestWarning: Unverified HTTPS request is being made to host 'www.yellowpages.ca'. Adding certificate verification is strongly advised. See: https://urllib3.readthedocs.io/en/1.26.x/advanced-usage.html#ssl-warnings
#   warnings.warn(
# retrieving  https://www.yellowpages.ca/search/si/2/Dentists/toronto+ON
# c:\Users\User\anaconda3\lib\site-packages\urllib3\connectionpool.py:1043: InsecureRequestWarning: Unverified HTTPS request is being made to host 'www.yellowpages.ca'. Adding certificate verification is strongly advised. See: https://urllib3.readthedocs.io/en/1.26.x/advanced-usage.html#ssl-warnings
#   warnings.warn(
# c:\Users\User\anaconda3\lib\site-packages\urllib3\connectionpool.py:1043: InsecureRequestWarning: Unverified HTTPS request is being made to host 'www.yellowpages.ca'. Adding certificate verification is strongly advised. See: https://urllib3.readthedocs.io/en/1.26.x/advanced-usage.html#ssl-warnings
#   warnings.warn(
# retrieving  https://www.yellowpages.ca/search/si/3/Dentists/toronto+ON
# c:\Users\User\anaconda3\lib\site-packages\urllib3\connectionpool.py:1043: InsecureRequestWarning: Unverified HTTPS request is being made to host 'www.yellowpages.ca'. Adding certificate verification is strongly advised. See: https://urllib3.readthedocs.io/en/1.26.x/advanced-usage.html#ssl-warnings
#   warnings.warn(
# c:\Users\User\anaconda3\lib\site-packages\urllib3\connectionpool.py:1043: InsecureRequestWarning: Unverified HTTPS request is being made to host 'www.yellowpages.ca'. Adding certificate verification is strongly advised. See: https://urllib3.readthedocs.io/en/1.26.x/advanced-usage.html#ssl-warnings
#   warnings.warn(
# retrieving  https://www.yellowpages.ca/search/si/4/Dentists/toronto+ON
# c:\Users\User\anaconda3\lib\site-packages\urllib3\connectionpool.py:1043: InsecureRequestWarning: Unverified HTTPS request is being made to host 'www.yellowpages.ca'. Adding certificate verification is strongly advised. See: https://urllib3.readthedocs.io/en/1.26.x/advanced-usage.html#ssl-warnings
#   warnings.warn(
# c:\Users\User\anaconda3\lib\site-packages\urllib3\connectionpool.py:1043: InsecureRequestWarning: Unverified HTTPS request is being made to host 'www.yellowpages.ca'. Adding certificate verification is strongly advised. See: https://urllib3.readthedocs.io/en/1.26.x/advanced-usage.html#ssl-warnings
#   warnings.warn(
# [[{'business_name': 'AIMS Dentistry at Sheppard',
#    'street': '2048 Sheppard Ave E',
#    'website': 'https://www.yellowpages.ca/gourl/eaeece855862c6db90a46299b8f9505b342a2f5c?redirect=https%3A%2F%2Fdentistryatsheppard.com%2F',
#    'city': 'North York',
#    'region': 'ON',
#    'zipcode': 'M2J 5B3',
#    'industry': 'Dentists',
#    'phone': '647-846-2317',
#    'product': None,
#    'description': 'Dentist'},
#   {'business_name': 'City Oasis Dental',
#    'street': '82 Adelaide St E',
#    'website': 'https://www.yellowpages.ca/gourl/5757443dc0e037ad5f02af9025c59b499e463144?redirect=http%3A%2F%2Fcityoasis.dental%2F',
#    'city': 'Toronto',
#    'region': 'ON',
#    'zipcode': 'M5C 1K9',
#    'industry': 'Dentists',
#    'phone': '647-342-4868',
#    'product': 'General Dentist, Cosmetic Dentist',
#    'description': 'City Oasis Dental strives to provide the highest quality dental care in Toronto in a relaxing & comfortable spa environment. Dental care has never been this comfortable. Call today for an appointment!\nmore...\nSee more text'},
#   {'business_name': 'Pape Dental Centre',
#    'street': '759 Pape Ave',
#    'website': 'https://www.yellowpages.ca/gourl/83db23f52f49541a02de749f6efe3c77d0b7a692?redirect=http%3A%2F%2Fwww.papedental.ca%2F',
#    'city': 'Toronto',
#    'region': 'ON',
#    'zipcode': 'M4K 3T2',
#    'industry': 'Dentists',
#    'phone': '647-558-2829',
#    'product': "Halkiotis Jane Dr, General Dental Practice, General Dentistry, Kid's Dentist, Wide Range Of Dental Services, Family Dentistry, Dentist Office, Dental Care, Dental Clinic, Dental Surgeon, Cosmetic Dentistry",
#    'description': 'Family And Cosmetic Dentistry Serving Toronto Area'},
#   {'business_name': 'Eglinton West Dental',
#    'street': '1114 Eglinton Ave W',
#    'website': 'https://www.yellowpages.ca/gourl/63000c37de3cc60038ab4414c509ae7fc2f59a46?redirect=http%3A%2F%2Feglintonwestdental.ca%2F',
#    'city': 'Toronto',
#    'region': 'ON',
#    'zipcode': 'M6C 2E2',
#    'industry': 'Dentists',
#    'phone': '647-484-2557',
#    'product': None,
#    'description': 'Beautiful smiles are made here ! We offer preventitive, restorative and cosmetic dental services. Gentle Dental Treatment for patients of all ages in Upper Village of Forest Hill.\nmore...\nSee more text'},
#   {'business_name': 'Dentistry on Danforth',
#    'street': '249 Danforth Ave',
#    'website': 'https://www.yellowpages.ca/gourl/7f395eeaa1d349ff12ed3839a3218319ebc1690f?redirect=http%3A%2F%2Fwww.dentistryondanforth.com%2F',
#    'city': 'Toronto',
#    'region': 'ON',
#    'zipcode': 'M4K 1N2',
#    'industry': 'Dentists',
#    'phone': '647-360-3815',
#    'product': 'Dr K Papadopoulos, General And Preventive Dentistry, Dentist, Cleanings, Restorative Dentistry, Implant Dentistry, Cosmetic Dentistry, General Dentist, Community Dentistry, Tooth-Coloured Fillings, Crowns',
#    'description': 'Dentistry on Danforth Provides Comprehensive Dentistry In One Location-Preventive & General Dentistry, Cosmetic, Implant and Restorative Dentistry\nmore...\nSee more text'},
#   {'business_name': 'Orthodontics on Danforth',
#    'street': '758 Danforth Ave',
#    'website': 'https://www.yellowpages.ca/gourl/b9699056edeb295e39593e8c2b3ce163807b8e4d?redirect=http%3A%2F%2Fwww.orthodonticsondanforth.com%2F',
#    'city': 'Toronto',
#    'region': 'ON',
#    'zipcode': 'M4J 1L5',
#    'industry': 'Dentists',
#    'phone': '647-559-9324',
#    'product': 'Orthodontist',
#    'description': 'A dental specialist in Orthodontics, providing comprehensive orthodontic care for all ages, in a friendly and family-oriented environment.\nmore...\nSee more text'},
#   {'business_name': 'Dr Steven & Dr Jonathan Stern Dentistry',
#    'street': '2-49 Eglinton Ave E',
#    'website': 'https://www.yellowpages.ca/gourl/6e2aa6da77a3cc992e3e272a6eded1d8a917e2af?redirect=http%3A%2F%2Fdrstern.ca%2F',
#    'city': 'Toronto',
#    'region': 'ON',
#    'zipcode': 'M4P 1G6',
#    'industry': 'Dentists',
#    'phone': '647-846-7243',
#    'product': 'Steven Stern, Community Dentist, General Dentist',
#    'description': 'Don’t let your anxiety about going to the dentist keep you from getting the care you need!'},
#   {'business_name': 'Dr Richard Styka Dentistry Professional Corporation',
#    'street': '1588 Bloor St W',
#    'website': 'https://www.yellowpages.ca/gourl/d6cd13dca9042e80d60290f203e3d79d405b923f?redirect=http%3A%2F%2Fdrstyka.com%2F',
#    'city': 'Toronto',
#    'region': 'ON',
#    'zipcode': 'M6P 1A7',
#    'industry': 'Dentists',
#    'phone': '647-795-9160',
#    'product': 'Family Dentistry',
#    'description': 'Family & Cosmetic Dentistry'},
#   {'business_name': 'Strugurescu M Dr',
#    'street': '309-745 Danforth Ave',
#    'website': 'https://www.yellowpages.ca/gourl/8d2066c2cd9b7e59ec922bfa506650687b044e17?redirect=http%3A%2F%2Fwww.danforthdentistry.com%2F',
#    'city': 'Toronto',
#    'region': 'ON',
#    'zipcode': 'M4J 1L4',
#    'industry': 'Dentists',
#    'phone': '416-687-2899',
#    'product': 'General Dentist',
#    'description': 'Dr. Michael Strugurescu focuses on aiding and maintaining complete oral health. He also provides cosmetic dental treatments which can help patients experience the smile they have always wanted.\nmore...\nSee more text'},
#   {'business_name': 'Vernon Koo',
#    'street': '1920 Yonge St',
#    'website': 'https://www.yellowpages.ca/gourl/eb61da60f0049fae073149bc6440eed6bc39c7d4?redirect=http%3A%2F%2Fwww.yongedavisvilledentistry.com%2F',
#    'city': 'Toronto',
#    'region': 'ON',
#    'zipcode': 'M4S 3E2',
#    'industry': 'Dentists',
#    'phone': '647-498-0073',
#    'product': 'Periodontists',
#    'description': 'Comprehensive General Practice-New Patients & Emergencies Welcome-Cosmetic Dentistry, Family Dentistry. Located Above Davisville Subway. Entrance From Yonge St. Evening Appointments Available.\nmore...\nSee more text'},
#   {'business_name': 'Canadian Orthodontic Partners Ulc',
#    'street': '2200 Yonge St',
#    'website': 'https://www.yellowpages.ca/gourl/ec6a11e0f09d754f3bc4c7d68b843ecb68ca8df1?redirect=http%3A%2F%2Fwww.metaxasortho.ca%2F',
#    'city': 'Toronto',
#    'region': 'ON',
#    'zipcode': 'M4S 2C6',
#    'industry': 'Dentists',
#    'phone': '416-482-4564',
#    'product': 'General Dentist',
#    'description': 'Never underestimate the power of your smile!'},
#   {'business_name': 'Yonge Eglinton Periodontics & Implant Surgery',
#    'street': '706-2300 Yonge St',
#    'website': 'https://www.yellowpages.ca/gourl/1f6b8d0e429f8acd4ba4cfd3428e404d281d1e8a?redirect=http%3A%2F%2Fwww.drandrewkay.com%2F',
#    'city': 'Toronto',
#    'region': 'ON',
#    'zipcode': 'M4P 1E4',
#    'industry': 'Dentists',
#    'phone': '416-481-1179',
#    'product': 'Dr Andrew Kay, Periodontal and Dental Implants',
#    'description': 'Located in Toronto, Yonge Eglinton Periodontics & Implant Surgery offers a range of care options for better oral health. Our services include bone grafts, dental implants, extracti...\nmore...\nSee more text'},
#   {'business_name': 'Endodontic Specialists',
#    'street': '201-1235 Bay St',
#    'website': 'https://www.yellowpages.ca/gourl/11b78abf35bf7d20f7eceef94a4d9ab7fbd63452?redirect=http%3A%2F%2Fwww.rootcanals.ca%2F',
#    'city': 'Toronto',
#    'region': 'ON',
#    'zipcode': 'M5R 3K4',
#    'industry': 'Dentists',
#    'phone': '416-963-9988',
#    'product': 'Endodontic, Endodontist, Root Canal Specialist',
#    'description': 'At Endodontic Specialists in Toronto, we not only provide expert endodontic services, but we also provide warm and friendly service, that will put you at ease the second you walk t...\nmore...\nSee more text'},
#   {'business_name': 'Royal Bank Plaza Dental Centre',
#    'street': '200 Bay St',
#    'website': 'https://www.yellowpages.ca/gourl/40e5ed1b39e783a7886bf41ccfc5a849da0c11d5?redirect=http%3A%2F%2Fwww.royaldentalcentre.com%2F',
#    'city': 'Toronto',
#    'region': 'ON',
#    'zipcode': 'M5J 2J3',
#    'industry': 'Dentists',
#    'phone': '437-889-3282',
#    'product': None,
#    'description': 'Oral Hygiene/Preventive Care Teeth Whitening  Implants Crown/bridges/veneers Dentures/Extractions Sports Mouth Guards/TMJ night guards Complimentary Cosmetic Consultation Orthodontics & Invisalign\nmore...\nSee more text'},
#   {'business_name': 'Dr Paul S Monczka',
#    'street': '103-795 Eglinton Ave E',
#    'website': None,
#    'city': 'East York',
#    'region': 'ON',
#    'zipcode': 'M4G 4E4',
#    'industry': 'Dentists',
#    'phone': '416-424-3477',
#    'product': None,
#    'description': None},
#   {'business_name': 'Dagys Arlene P Dr',
#    'street': '340 Kingston Rd',
#    'website': 'https://www.yellowpages.ca/gourl/4a309a7dffa09bcc2aa799f30f525d12e59980b2?redirect=http%3A%2F%2Fwww.facebook.com%2F1701420380146028',
#    'city': 'Toronto',
#    'region': 'ON',
#    'zipcode': 'M4L 1T7',
#    'industry': 'Dentists',
#    'phone': '416-690-8525',
#    'product': None,
#    'description': 'Dagys Arlene P Dr is a Toronto-based dentist. Whether you need a general oral health check-up, or you have a dental emergency, our experienced team can help. Give us a call to arra...\nmore...\nSee more text'},
#   {'business_name': 'Dr Robert Elia',
#    'street': '175 York Mills Rd',
#    'website': 'https://www.yellowpages.ca/gourl/e125d9dcacdb558d51e01037f15896d7560fc8fc?redirect=http%3A%2F%2Fwww.facebook.com%2F760044720798682',
#    'city': 'North York',
#    'region': 'ON',
#    'zipcode': 'M2L 1K6',
#    'industry': 'Dentists',
#    'phone': '416-512-6431',
#    'product': None,
#    'description': 'Dr Elia is proud North York Dentist'},
#   {'business_name': 'Dr Marta Prystayko',
#    'street': '305-2425 Bloor St W',
#    'website': 'https://www.yellowpages.ca/gourl/5602e0233f7f0bf47521fbaaa20dde96462ea99f?redirect=http%3A%2F%2Fwww.facebook.com%2F1186411154705330',
#    'city': 'Toronto',
#    'region': 'ON',
#    'zipcode': 'M6S 4W4',
#    'industry': 'Dentists',
#    'phone': '647-484-2943',
#    'product': 'General Dentist, Family Dentist, Cosmetic Services, Root Canal, Dental Implant Consultations, Periodontal Service And Hygiene, Children Dentistry, Teeth Cleaning And Whitening, Sports Mouth Guards',
#    'description': 'Practicing family dentistry in the Bloor West community for over 30 years.'},
#   {'business_name': 'Dr Violeta Danciu',
#    'street': '2329 Dundas St W',
#    'website': 'https://www.yellowpages.ca/gourl/82caff302248bdfafe016626db7f9292b379527f?redirect=http%3A%2F%2Fwww.danciudentist.com%2F',
#    'city': 'Toronto',
#    'region': 'ON',
#    'zipcode': 'M6R 1X6',
#    'industry': 'Dentists',
#    'phone': '416-533-4973',
#    'product': None,
#    'description': 'Dr. Violeta Danciu is an experienced Toronto family dentist who provides truly exceptional dental care and satisfaction to for her patients over many years. Contact our clinic today!\nmore...\nSee more text'},
#   {'business_name': 'Lombard dental Dr. Kerry Lim',
#    'street': '2 Lombard St',
#    'website': 'https://www.yellowpages.ca/gourl/d06d6e7b7c997a2f872f5d55e69e9dfff411e6d0?redirect=http%3A%2F%2Fwww.drkerrylim.com%2F',
#    'city': 'Toronto',
#    'region': 'ON',
#    'zipcode': 'M5C 1M1',
#    'industry': 'Dentists',
#    'phone': '416-362-3875',
#    'product': 'General Dentist',
#    'description': 'We believe in having winning smiles and healthy teeth that last a lifetime.'},
#   {'business_name': 'Dr Brian Kotzer',
#    'street': '510-18 King St E',
#    'website': 'https://www.yellowpages.ca/gourl/50082baa114013aaf7978030d75e8d0bed3ef4f7?redirect=http%3A%2F%2Fyongedentalcentre.com%2Findex.php',
#    'city': 'Toronto',
#    'region': 'ON',
#    'zipcode': 'M5C 1C4',
#    'industry': 'Dentists',
#    'phone': '416-367-0212',
#    'product': 'Yonge Dental Centre, Family Dentistry, General & Cosmetic Dentistry',
#    'description': 'Dr. Brian Kotzer   Dr. Paul Wright   Dr. Jennifer Kotzer Dr. Robert Kotzer'},
#   {'business_name': 'Dr Mark Nusinoff',
#    'street': '203-2179 Yonge St',
#    'website': 'https://www.yellowpages.ca/gourl/295951486537e1125e8235a8412a0d672fde46ba?redirect=https%3A%2F%2Fyongestreetdental.com%2F',
#    'city': 'Toronto',
#    'region': 'ON',
#    'zipcode': 'M4S 2B1',
#    'industry': 'Dentists',
#    'phone': '416-488-6633',
#    'product': 'Yonge Street Dental,',
#    'description': None},
#   {'business_name': 'Mazzatto Anthony Dr',
#    'street': '65 Queen St W',
#    'website': None,
#    'city': 'Toronto',
#    'region': 'ON',
#    'zipcode': 'M5H 2M5',
#    'industry': 'Dentists',
#    'phone': '416-368-9949',
#    'product': None,
#    'description': 'Dr. Anthony Mazzatto welcomes new patients to his dental office located in downtown Toronto. Offering family dental services, Dr. Mazzatto will be glad to assist you in your way to...\nmore...\nSee more text'},
#   {'business_name': 'Dr Paul Wright',
#    'street': '510-18 King St E',
#    'website': 'https://www.yellowpages.ca/gourl/50082baa114013aaf7978030d75e8d0bed3ef4f7?redirect=http%3A%2F%2Fyongedentalcentre.com%2Findex.php',
#    'city': 'Toronto',
#    'region': 'ON',
#    'zipcode': 'M5C 1C4',
#    'industry': 'Dentists',
#    'phone': '416-367-0212',
#    'product': 'Yonge Dental Centre, Dental Care For All Ages',
#    'description': 'Dr. Brian Kotzer   Dr. Paul Wright   Dr. Jennifer Kotzer Dr. Robert Kotzer\nmore...\nSee more text'},
#   {'business_name': 'Forest Hill Village Orthodontics',
#    'street': '740 Eglinton Ave W',
#    'website': 'https://www.yellowpages.ca/gourl/78286d0dfa3216d6b9445622150ac74ed414feb5?redirect=http%3A%2F%2Fwww.foresthillvillageorthodontics.com%2F',
#    'city': 'Toronto',
#    'region': 'ON',
#    'zipcode': 'M5N 1C4',
#    'industry': 'Dentists',
#    'phone': '416-789-1231',
#    'product': 'ORTHODONTISTS,',
#    'description': "Located in Toronto and Aurora, Ontario, our practice's top priority is to provide you the highest quality orthodontic care in a friendly, comfortable environment\nmore...\nSee more text"},
#   {'business_name': 'Oral Surgery Practice',
#    'street': '340 College St',
#    'website': None,
#    'city': 'Toronto',
#    'region': 'ON',
#    'zipcode': 'M5T 3A9',
#    'industry': 'Dentists',
#    'phone': '416-924-9673',
#    'product': 'oral & maxillofacial surgery',
#    'description': 'For reliable dental care in the downtown Toronto area, visit Oral Surgery Practice on College Street today. Our talented and professional dentists take your well-being into account...\nmore...\nSee more text'},
#   {'business_name': 'Dr Robert Kotzer',
#    'street': '510-18 King St E',
#    'website': 'https://www.yellowpages.ca/gourl/50082baa114013aaf7978030d75e8d0bed3ef4f7?redirect=http%3A%2F%2Fyongedentalcentre.com%2Findex.php',
#    'city': 'Toronto',
#    'region': 'ON',
#    'zipcode': 'M5C 1C4',
#    'industry': 'Dentists',
#    'phone': '416-367-0212',
#    'product': 'Yonge Dental Centre, Dental Care For All Ages',
#    'description': 'Dr. Brian Kotzer   Dr. Paul Wright   Dr. Jennifer Kotzer Dr. Robert Kotzer'},
#   {'business_name': 'Scarlett Road Dentistry',
#    'street': '263 Scarlett Rd',
#    'website': 'https://www.yellowpages.ca/gourl/e70c4c24eaf9fffda2a76ba48391eb0e1c3b4d55?redirect=http%3A%2F%2Fwww.scarlettroaddentistry.com%2F',
#    'city': 'York',
#    'region': 'ON',
#    'zipcode': 'M6N 4L1',
#    'industry': 'Dentists',
#    'phone': '416-763-3773',
#    'product': 'Dr Lorne Levy,',
#    'description': None},
#   {'business_name': 'Dr Jennifer Kotzer',
#    'street': '510-18 King St E',
#    'website': 'https://www.yellowpages.ca/gourl/50082baa114013aaf7978030d75e8d0bed3ef4f7?redirect=http%3A%2F%2Fyongedentalcentre.com%2Findex.php',
#    'city': 'Toronto',
#    'region': 'ON',
#    'zipcode': 'M5C 1C4',
#    'industry': 'Dentists',
#    'phone': '416-367-0212',
#    'product': 'Yonge Dental Centre, Family Dentistry, General & Cosmetic Dentistry',
#    'description': 'Dr. Brian Kotzer   Dr. Paul Wright   Dr. Jennifer Kotzer Dr. Robert Kotzer'}],
#  [{'business_name': 'AIMS Dentistry at Sheppard',
#    'street': '2048 Sheppard Ave E',
#    'website': 'https://www.yellowpages.ca/gourl/eaeece855862c6db90a46299b8f9505b342a2f5c?redirect=https%3A%2F%2Fdentistryatsheppard.com%2F',
#    'city': 'North York',
#    'region': 'ON',
#    'zipcode': 'M2J 5B3',
#    'industry': 'Dentists',
#    'phone': '647-846-2317',
#    'product': None,
#    'description': 'Dentist'},
#   {'business_name': 'City Oasis Dental',
#    'street': '82 Adelaide St E',
#    'website': 'https://www.yellowpages.ca/gourl/5757443dc0e037ad5f02af9025c59b499e463144?redirect=http%3A%2F%2Fcityoasis.dental%2F',
#    'city': 'Toronto',
#    'region': 'ON',
#    'zipcode': 'M5C 1K9',
#    'industry': 'Dentists',
#    'phone': '647-342-4868',
#    'product': 'General Dentist, Cosmetic Dentist',
#    'description': 'City Oasis Dental strives to provide the highest quality dental care in Toronto in a relaxing & comfortable spa environment. Dental care has never been this comfortable. Call today for an appointment!\nmore...\nSee more text'},
#   {'business_name': 'Pape Dental Centre',
#    'street': '759 Pape Ave',
#    'website': 'https://www.yellowpages.ca/gourl/83db23f52f49541a02de749f6efe3c77d0b7a692?redirect=http%3A%2F%2Fwww.papedental.ca%2F',
#    'city': 'Toronto',
#    'region': 'ON',
#    'zipcode': 'M4K 3T2',
#    'industry': 'Dentists',
#    'phone': '647-558-2829',
#    'product': "Halkiotis Jane Dr, General Dental Practice, General Dentistry, Kid's Dentist, Wide Range Of Dental Services, Family Dentistry, Dentist Office, Dental Care, Dental Clinic, Dental Surgeon, Cosmetic Dentistry",
#    'description': 'Family And Cosmetic Dentistry Serving Toronto Area'},
#   {'business_name': 'Eglinton West Dental',
#    'street': '1114 Eglinton Ave W',
#    'website': 'https://www.yellowpages.ca/gourl/63000c37de3cc60038ab4414c509ae7fc2f59a46?redirect=http%3A%2F%2Feglintonwestdental.ca%2F',
#    'city': 'Toronto',
#    'region': 'ON',
#    'zipcode': 'M6C 2E2',
#    'industry': 'Dentists',
#    'phone': '647-484-2557',
#    'product': None,
#    'description': 'Beautiful smiles are made here ! We offer preventitive, restorative and cosmetic dental services. Gentle Dental Treatment for patients of all ages in Upper Village of Forest Hill.\nmore...\nSee more text'},
#   {'business_name': 'Dr Steven & Dr Jonathan Stern Dentistry',
#    'street': '2-49 Eglinton Ave E',
#    'website': 'https://www.yellowpages.ca/gourl/6e2aa6da77a3cc992e3e272a6eded1d8a917e2af?redirect=http%3A%2F%2Fdrstern.ca%2F',
#    'city': 'Toronto',
#    'region': 'ON',
#    'zipcode': 'M4P 1G6',
#    'industry': 'Dentists',
#    'phone': '647-846-7243',
#    'product': 'Steven Stern, Community Dentist, General Dentist',
#    'description': 'Don’t let your anxiety about going to the dentist keep you from getting the care you need!'},
#   {'business_name': 'Dentistry on Danforth',
#    'street': '249 Danforth Ave',
#    'website': 'https://www.yellowpages.ca/gourl/7f395eeaa1d349ff12ed3839a3218319ebc1690f?redirect=http%3A%2F%2Fwww.dentistryondanforth.com%2F',
#    'city': 'Toronto',
#    'region': 'ON',
#    'zipcode': 'M4K 1N2',
#    'industry': 'Dentists',
#    'phone': '647-360-3815',
#    'product': 'Dr K Papadopoulos, General And Preventive Dentistry, Dentist, Cleanings, Restorative Dentistry, Implant Dentistry, Cosmetic Dentistry, General Dentist, Community Dentistry, Tooth-Coloured Fillings, Crowns',
#    'description': 'Dentistry on Danforth Provides Comprehensive Dentistry In One Location-Preventive & General Dentistry, Cosmetic, Implant and Restorative Dentistry\nmore...\nSee more text'},
#   {'business_name': 'Strugurescu M Dr',
#    'street': '309-745 Danforth Ave',
#    'website': 'https://www.yellowpages.ca/gourl/8d2066c2cd9b7e59ec922bfa506650687b044e17?redirect=http%3A%2F%2Fwww.danforthdentistry.com%2F',
#    'city': 'Toronto',
#    'region': 'ON',
#    'zipcode': 'M4J 1L4',
#    'industry': 'Dentists',
#    'phone': '416-687-2899',
#    'product': 'General Dentist',
#    'description': 'Dr. Michael Strugurescu focuses on aiding and maintaining complete oral health. He also provides cosmetic dental treatments which can help patients experience the smile they have always wanted.\nmore...\nSee more text'},
#   {'business_name': 'Orthodontics on Danforth',
#    'street': '758 Danforth Ave',
#    'website': 'https://www.yellowpages.ca/gourl/b9699056edeb295e39593e8c2b3ce163807b8e4d?redirect=http%3A%2F%2Fwww.orthodonticsondanforth.com%2F',
#    'city': 'Toronto',
#    'region': 'ON',
#    'zipcode': 'M4J 1L5',
#    'industry': 'Dentists',
#    'phone': '647-559-9324',
#    'product': 'Orthodontist',
#    'description': 'A dental specialist in Orthodontics, providing comprehensive orthodontic care for all ages, in a friendly and family-oriented environment.\nmore...\nSee more text'},
#   {'business_name': 'Vernon Koo',
#    'street': '1920 Yonge St',
#    'website': 'https://www.yellowpages.ca/gourl/eb61da60f0049fae073149bc6440eed6bc39c7d4?redirect=http%3A%2F%2Fwww.yongedavisvilledentistry.com%2F',
#    'city': 'Toronto',
#    'region': 'ON',
#    'zipcode': 'M4S 3E2',
#    'industry': 'Dentists',
#    'phone': '647-498-0073',
#    'product': 'Periodontists',
#    'description': 'Comprehensive General Practice-New Patients & Emergencies Welcome-Cosmetic Dentistry, Family Dentistry. Located Above Davisville Subway. Entrance From Yonge St. Evening Appointments Available.\nmore...\nSee more text'},
#   {'business_name': 'Dr Richard Styka Dentistry Professional Corporation',
#    'street': '1588 Bloor St W',
#    'website': 'https://www.yellowpages.ca/gourl/d6cd13dca9042e80d60290f203e3d79d405b923f?redirect=http%3A%2F%2Fdrstyka.com%2F',
#    'city': 'Toronto',
#    'region': 'ON',
#    'zipcode': 'M6P 1A7',
#    'industry': 'Dentists',
#    'phone': '647-795-9160',
#    'product': 'Family Dentistry',
#    'description': 'Family & Cosmetic Dentistry'},
#   {'business_name': 'Canadian Orthodontic Partners Ulc',
#    'street': '2200 Yonge St',
#    'website': 'https://www.yellowpages.ca/gourl/ec6a11e0f09d754f3bc4c7d68b843ecb68ca8df1?redirect=http%3A%2F%2Fwww.metaxasortho.ca%2F',
#    'city': 'Toronto',
#    'region': 'ON',
#    'zipcode': 'M4S 2C6',
#    'industry': 'Dentists',
#    'phone': '416-482-4564',
#    'product': 'General Dentist',
#    'description': 'Never underestimate the power of your smile!'},
#   {'business_name': 'Dr Paul S Monczka',
#    'street': '103-795 Eglinton Ave E',
#    'website': None,
#    'city': 'East York',
#    'region': 'ON',
#    'zipcode': 'M4G 4E4',
#    'industry': 'Dentists',
#    'phone': '416-424-3477',
#    'product': None,
#    'description': None},
#   {'business_name': 'Dr Robert Elia',
#    'street': '175 York Mills Rd',
#    'website': 'https://www.yellowpages.ca/gourl/e125d9dcacdb558d51e01037f15896d7560fc8fc?redirect=http%3A%2F%2Fwww.facebook.com%2F760044720798682',
#    'city': 'North York',
#    'region': 'ON',
#    'zipcode': 'M2L 1K6',
#    'industry': 'Dentists',
#    'phone': '416-512-6431',
#    'product': None,
#    'description': 'Dr Elia is proud North York Dentist'},
#   {'business_name': 'Royal Bank Plaza Dental Centre',
#    'street': '200 Bay St',
#    'website': 'https://www.yellowpages.ca/gourl/40e5ed1b39e783a7886bf41ccfc5a849da0c11d5?redirect=http%3A%2F%2Fwww.royaldentalcentre.com%2F',
#    'city': 'Toronto',
#    'region': 'ON',
#    'zipcode': 'M5J 2J3',
#    'industry': 'Dentists',
#    'phone': '437-889-3282',
#    'product': None,
#    'description': 'Oral Hygiene/Preventive Care Teeth Whitening  Implants Crown/bridges/veneers Dentures/Extractions Sports Mouth Guards/TMJ night guards Complimentary Cosmetic Consultation Orthodontics & Invisalign\nmore...\nSee more text'},
#   {'business_name': 'Endodontic Specialists',
#    'street': '201-1235 Bay St',
#    'website': 'https://www.yellowpages.ca/gourl/11b78abf35bf7d20f7eceef94a4d9ab7fbd63452?redirect=http%3A%2F%2Fwww.rootcanals.ca%2F',
#    'city': 'Toronto',
#    'region': 'ON',
#    'zipcode': 'M5R 3K4',
#    'industry': 'Dentists',
#    'phone': '416-963-9988',
#    'product': 'Endodontic, Endodontist, Root Canal Specialist',
#    'description': 'At Endodontic Specialists in Toronto, we not only provide expert endodontic services, but we also provide warm and friendly service, that will put you at ease the second you walk t...\nmore...\nSee more text'},
#   {'business_name': 'Dagys Arlene P Dr',
#    'street': '340 Kingston Rd',
#    'website': 'https://www.yellowpages.ca/gourl/4a309a7dffa09bcc2aa799f30f525d12e59980b2?redirect=http%3A%2F%2Fwww.facebook.com%2F1701420380146028',
#    'city': 'Toronto',
#    'region': 'ON',
#    'zipcode': 'M4L 1T7',
#    'industry': 'Dentists',
#    'phone': '416-690-8525',
#    'product': None,
#    'description': 'Dagys Arlene P Dr is a Toronto-based dentist. Whether you need a general oral health check-up, or you have a dental emergency, our experienced team can help. Give us a call to arra...\nmore...\nSee more text'},
#   {'business_name': 'Yonge Eglinton Periodontics & Implant Surgery',
#    'street': '706-2300 Yonge St',
#    'website': 'https://www.yellowpages.ca/gourl/1f6b8d0e429f8acd4ba4cfd3428e404d281d1e8a?redirect=http%3A%2F%2Fwww.drandrewkay.com%2F',
#    'city': 'Toronto',
#    'region': 'ON',
#    'zipcode': 'M4P 1E4',
#    'industry': 'Dentists',
#    'phone': '416-481-1179',
#    'product': 'Dr Andrew Kay, Periodontal and Dental Implants',
#    'description': 'Located in Toronto, Yonge Eglinton Periodontics & Implant Surgery offers a range of care options for better oral health. Our services include bone grafts, dental implants, extracti...\nmore...\nSee more text'},
#   {'business_name': 'Dr Violeta Danciu',
#    'street': '2329 Dundas St W',
#    'website': 'https://www.yellowpages.ca/gourl/82caff302248bdfafe016626db7f9292b379527f?redirect=http%3A%2F%2Fwww.danciudentist.com%2F',
#    'city': 'Toronto',
#    'region': 'ON',
#    'zipcode': 'M6R 1X6',
#    'industry': 'Dentists',
#    'phone': '416-533-4973',
#    'product': None,
#    'description': 'Dr. Violeta Danciu is an experienced Toronto family dentist who provides truly exceptional dental care and satisfaction to for her patients over many years. Contact our clinic today!\nmore...\nSee more text'},
#   {'business_name': 'Dr Marta Prystayko',
#    'street': '305-2425 Bloor St W',
#    'website': 'https://www.yellowpages.ca/gourl/5602e0233f7f0bf47521fbaaa20dde96462ea99f?redirect=http%3A%2F%2Fwww.facebook.com%2F1186411154705330',
#    'city': 'Toronto',
#    'region': 'ON',
#    'zipcode': 'M6S 4W4',
#    'industry': 'Dentists',
#    'phone': '647-484-2943',
#    'product': 'General Dentist, Family Dentist, Cosmetic Services, Root Canal, Dental Implant Consultations, Periodontal Service And Hygiene, Children Dentistry, Teeth Cleaning And Whitening, Sports Mouth Guards',
#    'description': 'Practicing family dentistry in the Bloor West community for over 30 years.'},
#   {'business_name': 'Dr Paul Wright',
#    'street': '510-18 King St E',
#    'website': 'https://www.yellowpages.ca/gourl/50082baa114013aaf7978030d75e8d0bed3ef4f7?redirect=http%3A%2F%2Fyongedentalcentre.com%2Findex.php',
#    'city': 'Toronto',
#    'region': 'ON',
#    'zipcode': 'M5C 1C4',
#    'industry': 'Dentists',
#    'phone': '416-367-0212',
#    'product': 'Yonge Dental Centre, Dental Care For All Ages',
#    'description': 'Dr. Brian Kotzer   Dr. Paul Wright   Dr. Jennifer Kotzer Dr. Robert Kotzer\nmore...\nSee more text'},
#   {'business_name': 'Oral Surgery Practice',
#    'street': '340 College St',
#    'website': None,
#    'city': 'Toronto',
#    'region': 'ON',
#    'zipcode': 'M5T 3A9',
#    'industry': 'Dentists',
#    'phone': '416-924-9673',
#    'product': 'oral & maxillofacial surgery',
#    'description': 'For reliable dental care in the downtown Toronto area, visit Oral Surgery Practice on College Street today. Our talented and professional dentists take your well-being into account...\nmore...\nSee more text'},
#   {'business_name': 'Dr Brian Kotzer',
#    'street': '510-18 King St E',
#    'website': 'https://www.yellowpages.ca/gourl/50082baa114013aaf7978030d75e8d0bed3ef4f7?redirect=http%3A%2F%2Fyongedentalcentre.com%2Findex.php',
#    'city': 'Toronto',
#    'region': 'ON',
#    'zipcode': 'M5C 1C4',
#    'industry': 'Dentists',
#    'phone': '416-367-0212',
#    'product': 'Yonge Dental Centre, Family Dentistry, General & Cosmetic Dentistry',
#    'description': 'Dr. Brian Kotzer   Dr. Paul Wright   Dr. Jennifer Kotzer Dr. Robert Kotzer'},
#   {'business_name': 'Dr Jennifer Kotzer',
#    'street': '510-18 King St E',
#    'website': 'https://www.yellowpages.ca/gourl/50082baa114013aaf7978030d75e8d0bed3ef4f7?redirect=http%3A%2F%2Fyongedentalcentre.com%2Findex.php',
#    'city': 'Toronto',
#    'region': 'ON',
#    'zipcode': 'M5C 1C4',
#    'industry': 'Dentists',
#    'phone': '416-367-0212',
#    'product': 'Yonge Dental Centre, Family Dentistry, General & Cosmetic Dentistry',
#    'description': 'Dr. Brian Kotzer   Dr. Paul Wright   Dr. Jennifer Kotzer Dr. Robert Kotzer'},
#   {'business_name': 'Dr Mark Nusinoff',
#    'street': '203-2179 Yonge St',
#    'website': 'https://www.yellowpages.ca/gourl/295951486537e1125e8235a8412a0d672fde46ba?redirect=https%3A%2F%2Fyongestreetdental.com%2F',
#    'city': 'Toronto',
#    'region': 'ON',
#    'zipcode': 'M4S 2B1',
#    'industry': 'Dentists',
#    'phone': '416-488-6633',
#    'product': 'Yonge Street Dental,',
#    'description': None},
#   {'business_name': 'Dr Robert Kotzer',
#    'street': '510-18 King St E',
#    'website': 'https://www.yellowpages.ca/gourl/50082baa114013aaf7978030d75e8d0bed3ef4f7?redirect=http%3A%2F%2Fyongedentalcentre.com%2Findex.php',
#    'city': 'Toronto',
#    'region': 'ON',
#    'zipcode': 'M5C 1C4',
#    'industry': 'Dentists',
#    'phone': '416-367-0212',
#    'product': 'Yonge Dental Centre, Dental Care For All Ages',
#    'description': 'Dr. Brian Kotzer   Dr. Paul Wright   Dr. Jennifer Kotzer Dr. Robert Kotzer'},
#   {'business_name': 'Mazzatto Anthony Dr',
#    'street': '65 Queen St W',
#    'website': None,
#    'city': 'Toronto',
#    'region': 'ON',
#    'zipcode': 'M5H 2M5',
#    'industry': 'Dentists',
#    'phone': '416-368-9949',
#    'product': None,
#    'description': 'Dr. Anthony Mazzatto welcomes new patients to his dental office located in downtown Toronto. Offering family dental services, Dr. Mazzatto will be glad to assist you in your way to...\nmore...\nSee more text'},
#   {'business_name': 'Lombard dental Dr. Kerry Lim',
#    'street': '2 Lombard St',
#    'website': 'https://www.yellowpages.ca/gourl/d06d6e7b7c997a2f872f5d55e69e9dfff411e6d0?redirect=http%3A%2F%2Fwww.drkerrylim.com%2F',
#    'city': 'Toronto',
#    'region': 'ON',
#    'zipcode': 'M5C 1M1',
#    'industry': 'Dentists',
#    'phone': '416-362-3875',
#    'product': 'General Dentist',
#    'description': 'We believe in having winning smiles and healthy teeth that last a lifetime.'},
#   {'business_name': 'Forest Hill Village Orthodontics',
#    'street': '740 Eglinton Ave W',
#    'website': 'https://www.yellowpages.ca/gourl/78286d0dfa3216d6b9445622150ac74ed414feb5?redirect=http%3A%2F%2Fwww.foresthillvillageorthodontics.com%2F',
#    'city': 'Toronto',
#    'region': 'ON',
#    'zipcode': 'M5N 1C4',
#    'industry': 'Dentists',
#    'phone': '416-789-1231',
#    'product': 'ORTHODONTISTS,',
#    'description': "Located in Toronto and Aurora, Ontario, our practice's top priority is to provide you the highest quality orthodontic care in a friendly, comfortable environment\nmore...\nSee more text"},
#   {'business_name': 'Scarlett Road Dentistry',
#    'street': '263 Scarlett Rd',
#    'website': 'https://www.yellowpages.ca/gourl/e70c4c24eaf9fffda2a76ba48391eb0e1c3b4d55?redirect=http%3A%2F%2Fwww.scarlettroaddentistry.com%2F',
#    'city': 'York',
#    'region': 'ON',
#    'zipcode': 'M6N 4L1',
#    'industry': 'Dentists',
#    'phone': '416-763-3773',
#    'product': 'Dr Lorne Levy,',
#    'description': None}],
#  [{'business_name': 'City Oasis Dental',
#    'street': '82 Adelaide St E',
#    'website': 'https://www.yellowpages.ca/gourl/5757443dc0e037ad5f02af9025c59b499e463144?redirect=http%3A%2F%2Fcityoasis.dental%2F',
#    'city': 'Toronto',
#    'region': 'ON',
#    'zipcode': 'M5C 1K9',
#    'industry': 'Dentists',
#    'phone': '647-342-4868',
#    'product': 'General Dentist, Cosmetic Dentist',
#    'description': 'City Oasis Dental strives to provide the highest quality dental care in Toronto in a relaxing & comfortable spa environment. Dental care has never been this comfortable. Call today for an appointment!\nmore...\nSee more text'},
#   {'business_name': 'AIMS Dentistry at Sheppard',
#    'street': '2048 Sheppard Ave E',
#    'website': 'https://www.yellowpages.ca/gourl/eaeece855862c6db90a46299b8f9505b342a2f5c?redirect=https%3A%2F%2Fdentistryatsheppard.com%2F',
#    'city': 'North York',
#    'region': 'ON',
#    'zipcode': 'M2J 5B3',
#    'industry': 'Dentists',
#    'phone': '647-846-2317',
#    'product': None,
#    'description': 'Dentist'},
#   {'business_name': 'Eglinton West Dental',
#    'street': '1114 Eglinton Ave W',
#    'website': 'https://www.yellowpages.ca/gourl/63000c37de3cc60038ab4414c509ae7fc2f59a46?redirect=http%3A%2F%2Feglintonwestdental.ca%2F',
#    'city': 'Toronto',
#    'region': 'ON',
#    'zipcode': 'M6C 2E2',
#    'industry': 'Dentists',
#    'phone': '647-484-2557',
#    'product': None,
#    'description': 'Beautiful smiles are made here ! We offer preventitive, restorative and cosmetic dental services. Gentle Dental Treatment for patients of all ages in Upper Village of Forest Hill.\nmore...\nSee more text'},
#   {'business_name': 'Pape Dental Centre',
#    'street': '759 Pape Ave',
#    'website': 'https://www.yellowpages.ca/gourl/83db23f52f49541a02de749f6efe3c77d0b7a692?redirect=http%3A%2F%2Fwww.papedental.ca%2F',
#    'city': 'Toronto',
#    'region': 'ON',
#    'zipcode': 'M4K 3T2',
#    'industry': 'Dentists',
#    'phone': '647-558-2829',
#    'product': "Halkiotis Jane Dr, General Dental Practice, General Dentistry, Kid's Dentist, Wide Range Of Dental Services, Family Dentistry, Dentist Office, Dental Care, Dental Clinic, Dental Surgeon, Cosmetic Dentistry",
#    'description': 'Family And Cosmetic Dentistry Serving Toronto Area'},
#   {'business_name': 'Orthodontics on Danforth',
#    'street': '758 Danforth Ave',
#    'website': 'https://www.yellowpages.ca/gourl/b9699056edeb295e39593e8c2b3ce163807b8e4d?redirect=http%3A%2F%2Fwww.orthodonticsondanforth.com%2F',
#    'city': 'Toronto',
#    'region': 'ON',
#    'zipcode': 'M4J 1L5',
#    'industry': 'Dentists',
#    'phone': '647-559-9324',
#    'product': 'Orthodontist',
#    'description': 'A dental specialist in Orthodontics, providing comprehensive orthodontic care for all ages, in a friendly and family-oriented environment.\nmore...\nSee more text'},
#   {'business_name': 'Dr Richard Styka Dentistry Professional Corporation',
#    'street': '1588 Bloor St W',
#    'website': 'https://www.yellowpages.ca/gourl/d6cd13dca9042e80d60290f203e3d79d405b923f?redirect=http%3A%2F%2Fdrstyka.com%2F',
#    'city': 'Toronto',
#    'region': 'ON',
#    'zipcode': 'M6P 1A7',
#    'industry': 'Dentists',
#    'phone': '647-795-9160',
#    'product': 'Family Dentistry',
#    'description': 'Family & Cosmetic Dentistry'},
#   {'business_name': 'Vernon Koo',
#    'street': '1920 Yonge St',
#    'website': 'https://www.yellowpages.ca/gourl/eb61da60f0049fae073149bc6440eed6bc39c7d4?redirect=http%3A%2F%2Fwww.yongedavisvilledentistry.com%2F',
#    'city': 'Toronto',
#    'region': 'ON',
#    'zipcode': 'M4S 3E2',
#    'industry': 'Dentists',
#    'phone': '647-498-0073',
#    'product': 'Periodontists',
#    'description': 'Comprehensive General Practice-New Patients & Emergencies Welcome-Cosmetic Dentistry, Family Dentistry. Located Above Davisville Subway. Entrance From Yonge St. Evening Appointments Available.\nmore...\nSee more text'},
#   {'business_name': 'Dr Steven & Dr Jonathan Stern Dentistry',
#    'street': '2-49 Eglinton Ave E',
#    'website': 'https://www.yellowpages.ca/gourl/6e2aa6da77a3cc992e3e272a6eded1d8a917e2af?redirect=http%3A%2F%2Fdrstern.ca%2F',
#    'city': 'Toronto',
#    'region': 'ON',
#    'zipcode': 'M4P 1G6',
#    'industry': 'Dentists',
#    'phone': '647-846-7243',
#    'product': 'Steven Stern, Community Dentist, General Dentist',
#    'description': 'Don’t let your anxiety about going to the dentist keep you from getting the care you need!'},
#   {'business_name': 'Strugurescu M Dr',
#    'street': '309-745 Danforth Ave',
#    'website': 'https://www.yellowpages.ca/gourl/8d2066c2cd9b7e59ec922bfa506650687b044e17?redirect=http%3A%2F%2Fwww.danforthdentistry.com%2F',
#    'city': 'Toronto',
#    'region': 'ON',
#    'zipcode': 'M4J 1L4',
#    'industry': 'Dentists',
#    'phone': '416-687-2899',
#    'product': 'General Dentist',
#    'description': 'Dr. Michael Strugurescu focuses on aiding and maintaining complete oral health. He also provides cosmetic dental treatments which can help patients experience the smile they have always wanted.\nmore...\nSee more text'},
#   {'business_name': 'Dentistry on Danforth',
#    'street': '249 Danforth Ave',
#    'website': 'https://www.yellowpages.ca/gourl/7f395eeaa1d349ff12ed3839a3218319ebc1690f?redirect=http%3A%2F%2Fwww.dentistryondanforth.com%2F',
#    'city': 'Toronto',
#    'region': 'ON',
#    'zipcode': 'M4K 1N2',
#    'industry': 'Dentists',
#    'phone': '647-360-3815',
#    'product': 'Dr K Papadopoulos, General And Preventive Dentistry, Dentist, Cleanings, Restorative Dentistry, Implant Dentistry, Cosmetic Dentistry, General Dentist, Community Dentistry, Tooth-Coloured Fillings, Crowns',
#    'description': 'Dentistry on Danforth Provides Comprehensive Dentistry In One Location-Preventive & General Dentistry, Cosmetic, Implant and Restorative Dentistry\nmore...\nSee more text'},
#   {'business_name': 'Royal Bank Plaza Dental Centre',
#    'street': '200 Bay St',
#    'website': 'https://www.yellowpages.ca/gourl/40e5ed1b39e783a7886bf41ccfc5a849da0c11d5?redirect=http%3A%2F%2Fwww.royaldentalcentre.com%2F',
#    'city': 'Toronto',
#    'region': 'ON',
#    'zipcode': 'M5J 2J3',
#    'industry': 'Dentists',
#    'phone': '437-889-3282',
#    'product': None,
#    'description': 'Oral Hygiene/Preventive Care Teeth Whitening  Implants Crown/bridges/veneers Dentures/Extractions Sports Mouth Guards/TMJ night guards Complimentary Cosmetic Consultation Orthodontics & Invisalign\nmore...\nSee more text'},
#   {'business_name': 'Dr Robert Elia',
#    'street': '175 York Mills Rd',
#    'website': 'https://www.yellowpages.ca/gourl/e125d9dcacdb558d51e01037f15896d7560fc8fc?redirect=http%3A%2F%2Fwww.facebook.com%2F760044720798682',
#    'city': 'North York',
#    'region': 'ON',
#    'zipcode': 'M2L 1K6',
#    'industry': 'Dentists',
#    'phone': '416-512-6431',
#    'product': None,
#    'description': 'Dr Elia is proud North York Dentist'},
#   {'business_name': 'Dagys Arlene P Dr',
#    'street': '340 Kingston Rd',
#    'website': 'https://www.yellowpages.ca/gourl/4a309a7dffa09bcc2aa799f30f525d12e59980b2?redirect=http%3A%2F%2Fwww.facebook.com%2F1701420380146028',
#    'city': 'Toronto',
#    'region': 'ON',
#    'zipcode': 'M4L 1T7',
#    'industry': 'Dentists',
#    'phone': '416-690-8525',
#    'product': None,
#    'description': 'Dagys Arlene P Dr is a Toronto-based dentist. Whether you need a general oral health check-up, or you have a dental emergency, our experienced team can help. Give us a call to arra...\nmore...\nSee more text'},
#   {'business_name': 'Dr Paul S Monczka',
#    'street': '103-795 Eglinton Ave E',
#    'website': None,
#    'city': 'East York',
#    'region': 'ON',
#    'zipcode': 'M4G 4E4',
#    'industry': 'Dentists',
#    'phone': '416-424-3477',
#    'product': None,
#    'description': None},
#   {'business_name': 'Endodontic Specialists',
#    'street': '201-1235 Bay St',
#    'website': 'https://www.yellowpages.ca/gourl/11b78abf35bf7d20f7eceef94a4d9ab7fbd63452?redirect=http%3A%2F%2Fwww.rootcanals.ca%2F',
#    'city': 'Toronto',
#    'region': 'ON',
#    'zipcode': 'M5R 3K4',
#    'industry': 'Dentists',
#    'phone': '416-963-9988',
#    'product': 'Endodontic, Endodontist, Root Canal Specialist',
#    'description': 'At Endodontic Specialists in Toronto, we not only provide expert endodontic services, but we also provide warm and friendly service, that will put you at ease the second you walk t...\nmore...\nSee more text'},
#   {'business_name': 'Yonge Eglinton Periodontics & Implant Surgery',
#    'street': '706-2300 Yonge St',
#    'website': 'https://www.yellowpages.ca/gourl/1f6b8d0e429f8acd4ba4cfd3428e404d281d1e8a?redirect=http%3A%2F%2Fwww.drandrewkay.com%2F',
#    'city': 'Toronto',
#    'region': 'ON',
#    'zipcode': 'M4P 1E4',
#    'industry': 'Dentists',
#    'phone': '416-481-1179',
#    'product': 'Dr Andrew Kay, Periodontal and Dental Implants',
#    'description': 'Located in Toronto, Yonge Eglinton Periodontics & Implant Surgery offers a range of care options for better oral health. Our services include bone grafts, dental implants, extracti...\nmore...\nSee more text'},
#   {'business_name': 'Canadian Orthodontic Partners Ulc',
#    'street': '2200 Yonge St',
#    'website': 'https://www.yellowpages.ca/gourl/ec6a11e0f09d754f3bc4c7d68b843ecb68ca8df1?redirect=http%3A%2F%2Fwww.metaxasortho.ca%2F',
#    'city': 'Toronto',
#    'region': 'ON',
#    'zipcode': 'M4S 2C6',
#    'industry': 'Dentists',
#    'phone': '416-482-4564',
#    'product': 'General Dentist',
#    'description': 'Never underestimate the power of your smile!'},
#   {'business_name': 'Dr Violeta Danciu',
#    'street': '2329 Dundas St W',
#    'website': 'https://www.yellowpages.ca/gourl/82caff302248bdfafe016626db7f9292b379527f?redirect=http%3A%2F%2Fwww.danciudentist.com%2F',
#    'city': 'Toronto',
#    'region': 'ON',
#    'zipcode': 'M6R 1X6',
#    'industry': 'Dentists',
#    'phone': '416-533-4973',
#    'product': None,
#    'description': 'Dr. Violeta Danciu is an experienced Toronto family dentist who provides truly exceptional dental care and satisfaction to for her patients over many years. Contact our clinic today!\nmore...\nSee more text'},
#   {'business_name': 'Dr Marta Prystayko',
#    'street': '305-2425 Bloor St W',
#    'website': 'https://www.yellowpages.ca/gourl/5602e0233f7f0bf47521fbaaa20dde96462ea99f?redirect=http%3A%2F%2Fwww.facebook.com%2F1186411154705330',
#    'city': 'Toronto',
#    'region': 'ON',
#    'zipcode': 'M6S 4W4',
#    'industry': 'Dentists',
#    'phone': '647-484-2943',
#    'product': 'General Dentist, Family Dentist, Cosmetic Services, Root Canal, Dental Implant Consultations, Periodontal Service And Hygiene, Children Dentistry, Teeth Cleaning And Whitening, Sports Mouth Guards',
#    'description': 'Practicing family dentistry in the Bloor West community for over 30 years.'},
#   {'business_name': 'Dr Brian Kotzer',
#    'street': '510-18 King St E',
#    'website': 'https://www.yellowpages.ca/gourl/50082baa114013aaf7978030d75e8d0bed3ef4f7?redirect=http%3A%2F%2Fyongedentalcentre.com%2Findex.php',
#    'city': 'Toronto',
#    'region': 'ON',
#    'zipcode': 'M5C 1C4',
#    'industry': 'Dentists',
#    'phone': '416-367-0212',
#    'product': 'Yonge Dental Centre, Family Dentistry, General & Cosmetic Dentistry',
#    'description': 'Dr. Brian Kotzer   Dr. Paul Wright   Dr. Jennifer Kotzer Dr. Robert Kotzer'},
#   {'business_name': 'Forest Hill Village Orthodontics',
#    'street': '740 Eglinton Ave W',
#    'website': 'https://www.yellowpages.ca/gourl/78286d0dfa3216d6b9445622150ac74ed414feb5?redirect=http%3A%2F%2Fwww.foresthillvillageorthodontics.com%2F',
#    'city': 'Toronto',
#    'region': 'ON',
#    'zipcode': 'M5N 1C4',
#    'industry': 'Dentists',
#    'phone': '416-789-1231',
#    'product': 'ORTHODONTISTS,',
#    'description': "Located in Toronto and Aurora, Ontario, our practice's top priority is to provide you the highest quality orthodontic care in a friendly, comfortable environment\nmore...\nSee more text"},
#   {'business_name': 'Scarlett Road Dentistry',
#    'street': '263 Scarlett Rd',
#    'website': 'https://www.yellowpages.ca/gourl/e70c4c24eaf9fffda2a76ba48391eb0e1c3b4d55?redirect=http%3A%2F%2Fwww.scarlettroaddentistry.com%2F',
#    'city': 'York',
#    'region': 'ON',
#    'zipcode': 'M6N 4L1',
#    'industry': 'Dentists',
#    'phone': '416-763-3773',
#    'product': 'Dr Lorne Levy,',
#    'description': None},
#   {'business_name': 'Dr Paul Wright',
#    'street': '510-18 King St E',
#    'website': 'https://www.yellowpages.ca/gourl/50082baa114013aaf7978030d75e8d0bed3ef4f7?redirect=http%3A%2F%2Fyongedentalcentre.com%2Findex.php',
#    'city': 'Toronto',
#    'region': 'ON',
#    'zipcode': 'M5C 1C4',
#    'industry': 'Dentists',
#    'phone': '416-367-0212',
#    'product': 'Yonge Dental Centre, Dental Care For All Ages',
#    'description': 'Dr. Brian Kotzer   Dr. Paul Wright   Dr. Jennifer Kotzer Dr. Robert Kotzer\nmore...\nSee more text'},
#   {'business_name': 'Dr Jennifer Kotzer',
#    'street': '510-18 King St E',
#    'website': 'https://www.yellowpages.ca/gourl/50082baa114013aaf7978030d75e8d0bed3ef4f7?redirect=http%3A%2F%2Fyongedentalcentre.com%2Findex.php',
#    'city': 'Toronto',
#    'region': 'ON',
#    'zipcode': 'M5C 1C4',
#    'industry': 'Dentists',
#    'phone': '416-367-0212',
#    'product': 'Yonge Dental Centre, Family Dentistry, General & Cosmetic Dentistry',
#    'description': 'Dr. Brian Kotzer   Dr. Paul Wright   Dr. Jennifer Kotzer Dr. Robert Kotzer'},
#   {'business_name': 'Dr Robert Kotzer',
#    'street': '510-18 King St E',
#    'website': 'https://www.yellowpages.ca/gourl/50082baa114013aaf7978030d75e8d0bed3ef4f7?redirect=http%3A%2F%2Fyongedentalcentre.com%2Findex.php',
#    'city': 'Toronto',
#    'region': 'ON',
#    'zipcode': 'M5C 1C4',
#    'industry': 'Dentists',
#    'phone': '416-367-0212',
#    'product': 'Yonge Dental Centre, Dental Care For All Ages',
#    'description': 'Dr. Brian Kotzer   Dr. Paul Wright   Dr. Jennifer Kotzer Dr. Robert Kotzer'},
#   {'business_name': 'Dr Mark Nusinoff',
#    'street': '203-2179 Yonge St',
#    'website': 'https://www.yellowpages.ca/gourl/295951486537e1125e8235a8412a0d672fde46ba?redirect=https%3A%2F%2Fyongestreetdental.com%2F',
#    'city': 'Toronto',
#    'region': 'ON',
#    'zipcode': 'M4S 2B1',
#    'industry': 'Dentists',
#    'phone': '416-488-6633',
#    'product': 'Yonge Street Dental,',
#    'description': None},
#   {'business_name': 'Lombard dental Dr. Kerry Lim',
#    'street': '2 Lombard St',
# ...
#   {'business_name': 'Mazzatto Anthony Dr',
#    'street': '65 Queen St W',
#    'website': None,
#    'city': 'Toronto',
#    'region': 'ON',
#    'zipcode': 'M5H 2M5',
#    'industry': 'Dentists',
#    'phone': '416-368-9949',
#    'product': None,
#    'description': 'Dr. Anthony Mazzatto welcomes new patients to his dental office located in downtown Toronto. Offering family dental services, Dr. Mazzatto will be glad to assist you in your way to...\nmore...\nSee more text'}],
#  [{'business_name': 'AIMS Dentistry at Sheppard',
#    'street': '2048 Sheppard Ave E',
#    'website': 'https://www.yellowpages.ca/gourl/eaeece855862c6db90a46299b8f9505b342a2f5c?redirect=https%3A%2F%2Fdentistryatsheppard.com%2F',
#    'city': 'North York',
#    'region': 'ON',
#    'zipcode': 'M2J 5B3',
#    'industry': 'Dentists',
#    'phone': '647-846-2317',
#    'product': None,
#    'description': 'Dentist'},
#   {'business_name': 'City Oasis Dental',
#    'street': '82 Adelaide St E',
#    'website': 'https://www.yellowpages.ca/gourl/5757443dc0e037ad5f02af9025c59b499e463144?redirect=http%3A%2F%2Fcityoasis.dental%2F',
#    'city': 'Toronto',
#    'region': 'ON',
#    'zipcode': 'M5C 1K9',
#    'industry': 'Dentists',
#    'phone': '647-342-4868',
#    'product': 'General Dentist, Cosmetic Dentist',
#    'description': 'City Oasis Dental strives to provide the highest quality dental care in Toronto in a relaxing & comfortable spa environment. Dental care has never been this comfortable. Call today for an appointment!\nmore...\nSee more text'},
#   {'business_name': 'Pape Dental Centre',
#    'street': '759 Pape Ave',
#    'website': 'https://www.yellowpages.ca/gourl/83db23f52f49541a02de749f6efe3c77d0b7a692?redirect=http%3A%2F%2Fwww.papedental.ca%2F',
#    'city': 'Toronto',
#    'region': 'ON',
#    'zipcode': 'M4K 3T2',
#    'industry': 'Dentists',
#    'phone': '647-558-2829',
#    'product': "Halkiotis Jane Dr, General Dental Practice, General Dentistry, Kid's Dentist, Wide Range Of Dental Services, Family Dentistry, Dentist Office, Dental Care, Dental Clinic, Dental Surgeon, Cosmetic Dentistry",
#    'description': 'Family And Cosmetic Dentistry Serving Toronto Area'},
#   {'business_name': 'Eglinton West Dental',
#    'street': '1114 Eglinton Ave W',
#    'website': 'https://www.yellowpages.ca/gourl/63000c37de3cc60038ab4414c509ae7fc2f59a46?redirect=http%3A%2F%2Feglintonwestdental.ca%2F',
#    'city': 'Toronto',
#    'region': 'ON',
#    'zipcode': 'M6C 2E2',
#    'industry': 'Dentists',
#    'phone': '647-484-2557',
#    'product': None,
#    'description': 'Beautiful smiles are made here ! We offer preventitive, restorative and cosmetic dental services. Gentle Dental Treatment for patients of all ages in Upper Village of Forest Hill.\nmore...\nSee more text'},
#   {'business_name': 'Vernon Koo',
#    'street': '1920 Yonge St',
#    'website': 'https://www.yellowpages.ca/gourl/eb61da60f0049fae073149bc6440eed6bc39c7d4?redirect=http%3A%2F%2Fwww.yongedavisvilledentistry.com%2F',
#    'city': 'Toronto',
#    'region': 'ON',
#    'zipcode': 'M4S 3E2',
#    'industry': 'Dentists',
#    'phone': '647-498-0073',
#    'product': 'Periodontists',
#    'description': 'Comprehensive General Practice-New Patients & Emergencies Welcome-Cosmetic Dentistry, Family Dentistry. Located Above Davisville Subway. Entrance From Yonge St. Evening Appointments Available.\nmore...\nSee more text'},
#   {'business_name': 'Dentistry on Danforth',
#    'street': '249 Danforth Ave',
#    'website': 'https://www.yellowpages.ca/gourl/7f395eeaa1d349ff12ed3839a3218319ebc1690f?redirect=http%3A%2F%2Fwww.dentistryondanforth.com%2F',
#    'city': 'Toronto',
#    'region': 'ON',
#    'zipcode': 'M4K 1N2',
#    'industry': 'Dentists',
#    'phone': '647-360-3815',
#    'product': 'Dr K Papadopoulos, General And Preventive Dentistry, Dentist, Cleanings, Restorative Dentistry, Implant Dentistry, Cosmetic Dentistry, General Dentist, Community Dentistry, Tooth-Coloured Fillings, Crowns',
#    'description': 'Dentistry on Danforth Provides Comprehensive Dentistry In One Location-Preventive & General Dentistry, Cosmetic, Implant and Restorative Dentistry\nmore...\nSee more text'},
#   {'business_name': 'Dr Richard Styka Dentistry Professional Corporation',
#    'street': '1588 Bloor St W',
#    'website': 'https://www.yellowpages.ca/gourl/d6cd13dca9042e80d60290f203e3d79d405b923f?redirect=http%3A%2F%2Fdrstyka.com%2F',
#    'city': 'Toronto',
#    'region': 'ON',
#    'zipcode': 'M6P 1A7',
#    'industry': 'Dentists',
#    'phone': '647-795-9160',
#    'product': 'Family Dentistry',
#    'description': 'Family & Cosmetic Dentistry'},
#   {'business_name': 'Strugurescu M Dr',
#    'street': '309-745 Danforth Ave',
#    'website': 'https://www.yellowpages.ca/gourl/8d2066c2cd9b7e59ec922bfa506650687b044e17?redirect=http%3A%2F%2Fwww.danforthdentistry.com%2F',
#    'city': 'Toronto',
#    'region': 'ON',
#    'zipcode': 'M4J 1L4',
#    'industry': 'Dentists',
#    'phone': '416-687-2899',
#    'product': 'General Dentist',
#    'description': 'Dr. Michael Strugurescu focuses on aiding and maintaining complete oral health. He also provides cosmetic dental treatments which can help patients experience the smile they have always wanted.\nmore...\nSee more text'},
#   {'business_name': 'Orthodontics on Danforth',
#    'street': '758 Danforth Ave',
#    'website': 'https://www.yellowpages.ca/gourl/b9699056edeb295e39593e8c2b3ce163807b8e4d?redirect=http%3A%2F%2Fwww.orthodonticsondanforth.com%2F',
#    'city': 'Toronto',
#    'region': 'ON',
#    'zipcode': 'M4J 1L5',
#    'industry': 'Dentists',
#    'phone': '647-559-9324',
#    'product': 'Orthodontist',
#    'description': 'A dental specialist in Orthodontics, providing comprehensive orthodontic care for all ages, in a friendly and family-oriented environment.\nmore...\nSee more text'},
#   {'business_name': 'Dr Steven & Dr Jonathan Stern Dentistry',
#    'street': '2-49 Eglinton Ave E',
#    'website': 'https://www.yellowpages.ca/gourl/6e2aa6da77a3cc992e3e272a6eded1d8a917e2af?redirect=http%3A%2F%2Fdrstern.ca%2F',
#    'city': 'Toronto',
#    'region': 'ON',
#    'zipcode': 'M4P 1G6',
#    'industry': 'Dentists',
#    'phone': '647-846-7243',
#    'product': 'Steven Stern, Community Dentist, General Dentist',
#    'description': 'Don’t let your anxiety about going to the dentist keep you from getting the care you need!'},
#   {'business_name': 'Dr Violeta Danciu',
#    'street': '2329 Dundas St W',
#    'website': 'https://www.yellowpages.ca/gourl/82caff302248bdfafe016626db7f9292b379527f?redirect=http%3A%2F%2Fwww.danciudentist.com%2F',
#    'city': 'Toronto',
#    'region': 'ON',
#    'zipcode': 'M6R 1X6',
#    'industry': 'Dentists',
#    'phone': '416-533-4973',
#    'product': None,
#    'description': 'Dr. Violeta Danciu is an experienced Toronto family dentist who provides truly exceptional dental care and satisfaction to for her patients over many years. Contact our clinic today!\nmore...\nSee more text'},
#   {'business_name': 'Dagys Arlene P Dr',
#    'street': '340 Kingston Rd',
#    'website': 'https://www.yellowpages.ca/gourl/4a309a7dffa09bcc2aa799f30f525d12e59980b2?redirect=http%3A%2F%2Fwww.facebook.com%2F1701420380146028',
#    'city': 'Toronto',
#    'region': 'ON',
#    'zipcode': 'M4L 1T7',
#    'industry': 'Dentists',
#    'phone': '416-690-8525',
#    'product': None,
#    'description': 'Dagys Arlene P Dr is a Toronto-based dentist. Whether you need a general oral health check-up, or you have a dental emergency, our experienced team can help. Give us a call to arra...\nmore...\nSee more text'},
#   {'business_name': 'Dr Paul S Monczka',
#    'street': '103-795 Eglinton Ave E',
#    'website': None,
#    'city': 'East York',
#    'region': 'ON',
#    'zipcode': 'M4G 4E4',
#    'industry': 'Dentists',
#    'phone': '416-424-3477',
#    'product': None,
#    'description': None},
#   {'business_name': 'Royal Bank Plaza Dental Centre',
#    'street': '200 Bay St',
#    'website': 'https://www.yellowpages.ca/gourl/40e5ed1b39e783a7886bf41ccfc5a849da0c11d5?redirect=http%3A%2F%2Fwww.royaldentalcentre.com%2F',
#    'city': 'Toronto',
#    'region': 'ON',
#    'zipcode': 'M5J 2J3',
#    'industry': 'Dentists',
#    'phone': '437-889-3282',
#    'product': None,
#    'description': 'Oral Hygiene/Preventive Care Teeth Whitening  Implants Crown/bridges/veneers Dentures/Extractions Sports Mouth Guards/TMJ night guards Complimentary Cosmetic Consultation Orthodontics & Invisalign\nmore...\nSee more text'},
#   {'business_name': 'Endodontic Specialists',
#    'street': '201-1235 Bay St',
#    'website': 'https://www.yellowpages.ca/gourl/11b78abf35bf7d20f7eceef94a4d9ab7fbd63452?redirect=http%3A%2F%2Fwww.rootcanals.ca%2F',
#    'city': 'Toronto',
#    'region': 'ON',
#    'zipcode': 'M5R 3K4',
#    'industry': 'Dentists',
#    'phone': '416-963-9988',
#    'product': 'Endodontic, Endodontist, Root Canal Specialist',
#    'description': 'At Endodontic Specialists in Toronto, we not only provide expert endodontic services, but we also provide warm and friendly service, that will put you at ease the second you walk t...\nmore...\nSee more text'},
#   {'business_name': 'Dr Marta Prystayko',
#    'street': '305-2425 Bloor St W',
#    'website': 'https://www.yellowpages.ca/gourl/5602e0233f7f0bf47521fbaaa20dde96462ea99f?redirect=http%3A%2F%2Fwww.facebook.com%2F1186411154705330',
#    'city': 'Toronto',
#    'region': 'ON',
#    'zipcode': 'M6S 4W4',
#    'industry': 'Dentists',
#    'phone': '647-484-2943',
#    'product': 'General Dentist, Family Dentist, Cosmetic Services, Root Canal, Dental Implant Consultations, Periodontal Service And Hygiene, Children Dentistry, Teeth Cleaning And Whitening, Sports Mouth Guards',
#    'description': 'Practicing family dentistry in the Bloor West community for over 30 years.'},
#   {'business_name': 'Dr Robert Elia',
#    'street': '175 York Mills Rd',
#    'website': 'https://www.yellowpages.ca/gourl/e125d9dcacdb558d51e01037f15896d7560fc8fc?redirect=http%3A%2F%2Fwww.facebook.com%2F760044720798682',
#    'city': 'North York',
#    'region': 'ON',
#    'zipcode': 'M2L 1K6',
#    'industry': 'Dentists',
#    'phone': '416-512-6431',
#    'product': None,
#    'description': 'Dr Elia is proud North York Dentist'},
#   {'business_name': 'Yonge Eglinton Periodontics & Implant Surgery',
#    'street': '706-2300 Yonge St',
#    'website': 'https://www.yellowpages.ca/gourl/1f6b8d0e429f8acd4ba4cfd3428e404d281d1e8a?redirect=http%3A%2F%2Fwww.drandrewkay.com%2F',
#    'city': 'Toronto',
#    'region': 'ON',
#    'zipcode': 'M4P 1E4',
#    'industry': 'Dentists',
#    'phone': '416-481-1179',
#    'product': 'Dr Andrew Kay, Periodontal and Dental Implants',
#    'description': 'Located in Toronto, Yonge Eglinton Periodontics & Implant Surgery offers a range of care options for better oral health. Our services include bone grafts, dental implants, extracti...\nmore...\nSee more text'},
#   {'business_name': 'Canadian Orthodontic Partners Ulc',
#    'street': '2200 Yonge St',
#    'website': 'https://www.yellowpages.ca/gourl/ec6a11e0f09d754f3bc4c7d68b843ecb68ca8df1?redirect=http%3A%2F%2Fwww.metaxasortho.ca%2F',
#    'city': 'Toronto',
#    'region': 'ON',
#    'zipcode': 'M4S 2C6',
#    'industry': 'Dentists',
#    'phone': '416-482-4564',
#    'product': 'General Dentist',
#    'description': 'Never underestimate the power of your smile!'},
#   {'business_name': 'Oral Surgery Practice',
#    'street': '340 College St',
#    'website': None,
#    'city': 'Toronto',
#    'region': 'ON',
#    'zipcode': 'M5T 3A9',
#    'industry': 'Dentists',
#    'phone': '416-924-9673',
#    'product': 'oral & maxillofacial surgery',
#    'description': 'For reliable dental care in the downtown Toronto area, visit Oral Surgery Practice on College Street today. Our talented and professional dentists take your well-being into account...\nmore...\nSee more text'},
#   {'business_name': 'Mazzatto Anthony Dr',
#    'street': '65 Queen St W',
#    'website': None,
#    'city': 'Toronto',
#    'region': 'ON',
#    'zipcode': 'M5H 2M5',
#    'industry': 'Dentists',
#    'phone': '416-368-9949',
#    'product': None,
#    'description': 'Dr. Anthony Mazzatto welcomes new patients to his dental office located in downtown Toronto. Offering family dental services, Dr. Mazzatto will be glad to assist you in your way to...\nmore...\nSee more text'},
#   {'business_name': 'Dr Mark Nusinoff',
#    'street': '203-2179 Yonge St',
#    'website': 'https://www.yellowpages.ca/gourl/295951486537e1125e8235a8412a0d672fde46ba?redirect=https%3A%2F%2Fyongestreetdental.com%2F',
#    'city': 'Toronto',
#    'region': 'ON',
#    'zipcode': 'M4S 2B1',
#    'industry': 'Dentists',
#    'phone': '416-488-6633',
#    'product': 'Yonge Street Dental,',
#    'description': None},
#   {'business_name': 'Scarlett Road Dentistry',
#    'street': '263 Scarlett Rd',
#    'website': 'https://www.yellowpages.ca/gourl/e70c4c24eaf9fffda2a76ba48391eb0e1c3b4d55?redirect=http%3A%2F%2Fwww.scarlettroaddentistry.com%2F',
#    'city': 'York',
#    'region': 'ON',
#    'zipcode': 'M6N 4L1',
#    'industry': 'Dentists',
#    'phone': '416-763-3773',
#    'product': 'Dr Lorne Levy,',
#    'description': None},
#   {'business_name': 'Dr Paul Wright',
#    'street': '510-18 King St E',
#    'website': 'https://www.yellowpages.ca/gourl/50082baa114013aaf7978030d75e8d0bed3ef4f7?redirect=http%3A%2F%2Fyongedentalcentre.com%2Findex.php',
#    'city': 'Toronto',
#    'region': 'ON',
#    'zipcode': 'M5C 1C4',
#    'industry': 'Dentists',
#    'phone': '416-367-0212',
#    'product': 'Yonge Dental Centre, Dental Care For All Ages',
#    'description': 'Dr. Brian Kotzer   Dr. Paul Wright   Dr. Jennifer Kotzer Dr. Robert Kotzer\nmore...\nSee more text'},
#   {'business_name': 'Dr Robert Kotzer',
#    'street': '510-18 King St E',
#    'website': 'https://www.yellowpages.ca/gourl/50082baa114013aaf7978030d75e8d0bed3ef4f7?redirect=http%3A%2F%2Fyongedentalcentre.com%2Findex.php',
#    'city': 'Toronto',
#    'region': 'ON',
#    'zipcode': 'M5C 1C4',
#    'industry': 'Dentists',
#    'phone': '416-367-0212',
#    'product': 'Yonge Dental Centre, Dental Care For All Ages',
#    'description': 'Dr. Brian Kotzer   Dr. Paul Wright   Dr. Jennifer Kotzer Dr. Robert Kotzer'},
#   {'business_name': 'Lombard dental Dr. Kerry Lim',
#    'street': '2 Lombard St',
#    'website': 'https://www.yellowpages.ca/gourl/d06d6e7b7c997a2f872f5d55e69e9dfff411e6d0?redirect=http%3A%2F%2Fwww.drkerrylim.com%2F',
#    'city': 'Toronto',
#    'region': 'ON',
#    'zipcode': 'M5C 1M1',
#    'industry': 'Dentists',
#    'phone': '416-362-3875',
#    'product': 'General Dentist',
#    'description': 'We believe in having winning smiles and healthy teeth that last a lifetime.'},
#   {'business_name': 'Forest Hill Village Orthodontics',
#    'street': '740 Eglinton Ave W',
#    'website': 'https://www.yellowpages.ca/gourl/78286d0dfa3216d6b9445622150ac74ed414feb5?redirect=http%3A%2F%2Fwww.foresthillvillageorthodontics.com%2F',
#    'city': 'Toronto',
#    'region': 'ON',
#    'zipcode': 'M5N 1C4',
#    'industry': 'Dentists',
#    'phone': '416-789-1231',
#    'product': 'ORTHODONTISTS,',
#    'description': "Located in Toronto and Aurora, Ontario, our practice's top priority is to provide you the highest quality orthodontic care in a friendly, comfortable environment\nmore...\nSee more text"},
#   {'business_name': 'Dr Jennifer Kotzer',
#    'street': '510-18 King St E',
#    'website': 'https://www.yellowpages.ca/gourl/50082baa114013aaf7978030d75e8d0bed3ef4f7?redirect=http%3A%2F%2Fyongedentalcentre.com%2Findex.php',
#    'city': 'Toronto',
#    'region': 'ON',
#    'zipcode': 'M5C 1C4',
#    'industry': 'Dentists',
#    'phone': '416-367-0212',
#    'product': 'Yonge Dental Centre, Family Dentistry, General & Cosmetic Dentistry',
#    'description': 'Dr. Brian Kotzer   Dr. Paul Wright   Dr. Jennifer Kotzer Dr. Robert Kotzer'},
#   {'business_name': 'Dr Brian Kotzer',
#    'street': '510-18 King St E',
#    'website': 'https://www.yellowpages.ca/gourl/50082baa114013aaf7978030d75e8d0bed3ef4f7?redirect=http%3A%2F%2Fyongedentalcentre.com%2Findex.php',
#    'city': 'Toronto',
#    'region': 'ON',
#    'zipcode': 'M5C 1C4',
#    'industry': 'Dentists',
#    'phone': '416-367-0212',
#    'product': 'Yonge Dental Centre, Family Dentistry, General & Cosmetic Dentistry',
#    'description': 'Dr. Brian Kotzer   Dr. Paul Wright   Dr. Jennifer Kotzer Dr. Robert Kotzer'}]]

# %%
data[2]
# Out:
# [{'business_name': 'City Oasis Dental',
#   'street': '82 Adelaide St E',
#   'website': 'https://www.yellowpages.ca/gourl/5757443dc0e037ad5f02af9025c59b499e463144?redirect=http%3A%2F%2Fcityoasis.dental%2F',
#   'city': 'Toronto',
#   'region': 'ON',
#   'zipcode': 'M5C 1K9',
#   'industry': 'Dentists',
#   'phone': '647-342-4868',
#   'product': 'General Dentist, Cosmetic Dentist',
#   'description': 'City Oasis Dental strives to provide the highest quality dental care in Toronto in a relaxing & comfortable spa environment. Dental care has never been this comfortable. Call today for an appointment!\nmore...\nSee more text'},
#  {'business_name': 'AIMS Dentistry at Sheppard',
#   'street': '2048 Sheppard Ave E',
#   'website': 'https://www.yellowpages.ca/gourl/eaeece855862c6db90a46299b8f9505b342a2f5c?redirect=https%3A%2F%2Fdentistryatsheppard.com%2F',
#   'city': 'North York',
#   'region': 'ON',
#   'zipcode': 'M2J 5B3',
#   'industry': 'Dentists',
#   'phone': '647-846-2317',
#   'product': None,
#   'description': 'Dentist'},
#  {'business_name': 'Eglinton West Dental',
#   'street': '1114 Eglinton Ave W',
#   'website': 'https://www.yellowpages.ca/gourl/63000c37de3cc60038ab4414c509ae7fc2f59a46?redirect=http%3A%2F%2Feglintonwestdental.ca%2F',
#   'city': 'Toronto',
#   'region': 'ON',
#   'zipcode': 'M6C 2E2',
#   'industry': 'Dentists',
#   'phone': '647-484-2557',
#   'product': None,
#   'description': 'Beautiful smiles are made here ! We offer preventitive, restorative and cosmetic dental services. Gentle Dental Treatment for patients of all ages in Upper Village of Forest Hill.\nmore...\nSee more text'},
#  {'business_name': 'Pape Dental Centre',
#   'street': '759 Pape Ave',
#   'website': 'https://www.yellowpages.ca/gourl/83db23f52f49541a02de749f6efe3c77d0b7a692?redirect=http%3A%2F%2Fwww.papedental.ca%2F',
#   'city': 'Toronto',
#   'region': 'ON',
#   'zipcode': 'M4K 3T2',
#   'industry': 'Dentists',
#   'phone': '647-558-2829',
#   'product': "Halkiotis Jane Dr, General Dental Practice, General Dentistry, Kid's Dentist, Wide Range Of Dental Services, Family Dentistry, Dentist Office, Dental Care, Dental Clinic, Dental Surgeon, Cosmetic Dentistry",
#   'description': 'Family And Cosmetic Dentistry Serving Toronto Area'},
#  {'business_name': 'Orthodontics on Danforth',
#   'street': '758 Danforth Ave',
#   'website': 'https://www.yellowpages.ca/gourl/b9699056edeb295e39593e8c2b3ce163807b8e4d?redirect=http%3A%2F%2Fwww.orthodonticsondanforth.com%2F',
#   'city': 'Toronto',
#   'region': 'ON',
#   'zipcode': 'M4J 1L5',
#   'industry': 'Dentists',
#   'phone': '647-559-9324',
#   'product': 'Orthodontist',
#   'description': 'A dental specialist in Orthodontics, providing comprehensive orthodontic care for all ages, in a friendly and family-oriented environment.\nmore...\nSee more text'},
#  {'business_name': 'Dr Richard Styka Dentistry Professional Corporation',
#   'street': '1588 Bloor St W',
#   'website': 'https://www.yellowpages.ca/gourl/d6cd13dca9042e80d60290f203e3d79d405b923f?redirect=http%3A%2F%2Fdrstyka.com%2F',
#   'city': 'Toronto',
#   'region': 'ON',
#   'zipcode': 'M6P 1A7',
#   'industry': 'Dentists',
#   'phone': '647-795-9160',
#   'product': 'Family Dentistry',
#   'description': 'Family & Cosmetic Dentistry'},
#  {'business_name': 'Vernon Koo',
#   'street': '1920 Yonge St',
#   'website': 'https://www.yellowpages.ca/gourl/eb61da60f0049fae073149bc6440eed6bc39c7d4?redirect=http%3A%2F%2Fwww.yongedavisvilledentistry.com%2F',
#   'city': 'Toronto',
#   'region': 'ON',
#   'zipcode': 'M4S 3E2',
#   'industry': 'Dentists',
#   'phone': '647-498-0073',
#   'product': 'Periodontists',
#   'description': 'Comprehensive General Practice-New Patients & Emergencies Welcome-Cosmetic Dentistry, Family Dentistry. Located Above Davisville Subway. Entrance From Yonge St. Evening Appointments Available.\nmore...\nSee more text'},
#  {'business_name': 'Dr Steven & Dr Jonathan Stern Dentistry',
#   'street': '2-49 Eglinton Ave E',
#   'website': 'https://www.yellowpages.ca/gourl/6e2aa6da77a3cc992e3e272a6eded1d8a917e2af?redirect=http%3A%2F%2Fdrstern.ca%2F',
#   'city': 'Toronto',
#   'region': 'ON',
#   'zipcode': 'M4P 1G6',
#   'industry': 'Dentists',
#   'phone': '647-846-7243',
#   'product': 'Steven Stern, Community Dentist, General Dentist',
#   'description': 'Don’t let your anxiety about going to the dentist keep you from getting the care you need!'},
#  {'business_name': 'Strugurescu M Dr',
#   'street': '309-745 Danforth Ave',
#   'website': 'https://www.yellowpages.ca/gourl/8d2066c2cd9b7e59ec922bfa506650687b044e17?redirect=http%3A%2F%2Fwww.danforthdentistry.com%2F',
#   'city': 'Toronto',
#   'region': 'ON',
#   'zipcode': 'M4J 1L4',
#   'industry': 'Dentists',
#   'phone': '416-687-2899',
#   'product': 'General Dentist',
#   'description': 'Dr. Michael Strugurescu focuses on aiding and maintaining complete oral health. He also provides cosmetic dental treatments which can help patients experience the smile they have always wanted.\nmore...\nSee more text'},
#  {'business_name': 'Dentistry on Danforth',
#   'street': '249 Danforth Ave',
#   'website': 'https://www.yellowpages.ca/gourl/7f395eeaa1d349ff12ed3839a3218319ebc1690f?redirect=http%3A%2F%2Fwww.dentistryondanforth.com%2F',
#   'city': 'Toronto',
#   'region': 'ON',
#   'zipcode': 'M4K 1N2',
#   'industry': 'Dentists',
#   'phone': '647-360-3815',
#   'product': 'Dr K Papadopoulos, General And Preventive Dentistry, Dentist, Cleanings, Restorative Dentistry, Implant Dentistry, Cosmetic Dentistry, General Dentist, Community Dentistry, Tooth-Coloured Fillings, Crowns',
#   'description': 'Dentistry on Danforth Provides Comprehensive Dentistry In One Location-Preventive & General Dentistry, Cosmetic, Implant and Restorative Dentistry\nmore...\nSee more text'},
#  {'business_name': 'Royal Bank Plaza Dental Centre',
#   'street': '200 Bay St',
#   'website': 'https://www.yellowpages.ca/gourl/40e5ed1b39e783a7886bf41ccfc5a849da0c11d5?redirect=http%3A%2F%2Fwww.royaldentalcentre.com%2F',
#   'city': 'Toronto',
#   'region': 'ON',
#   'zipcode': 'M5J 2J3',
#   'industry': 'Dentists',
#   'phone': '437-889-3282',
#   'product': None,
#   'description': 'Oral Hygiene/Preventive Care Teeth Whitening  Implants Crown/bridges/veneers Dentures/Extractions Sports Mouth Guards/TMJ night guards Complimentary Cosmetic Consultation Orthodontics & Invisalign\nmore...\nSee more text'},
#  {'business_name': 'Dr Robert Elia',
#   'street': '175 York Mills Rd',
#   'website': 'https://www.yellowpages.ca/gourl/e125d9dcacdb558d51e01037f15896d7560fc8fc?redirect=http%3A%2F%2Fwww.facebook.com%2F760044720798682',
#   'city': 'North York',
#   'region': 'ON',
#   'zipcode': 'M2L 1K6',
#   'industry': 'Dentists',
#   'phone': '416-512-6431',
#   'product': None,
#   'description': 'Dr Elia is proud North York Dentist'},
#  {'business_name': 'Dagys Arlene P Dr',
#   'street': '340 Kingston Rd',
#   'website': 'https://www.yellowpages.ca/gourl/4a309a7dffa09bcc2aa799f30f525d12e59980b2?redirect=http%3A%2F%2Fwww.facebook.com%2F1701420380146028',
#   'city': 'Toronto',
#   'region': 'ON',
#   'zipcode': 'M4L 1T7',
#   'industry': 'Dentists',
#   'phone': '416-690-8525',
#   'product': None,
#   'description': 'Dagys Arlene P Dr is a Toronto-based dentist. Whether you need a general oral health check-up, or you have a dental emergency, our experienced team can help. Give us a call to arra...\nmore...\nSee more text'},
#  {'business_name': 'Dr Paul S Monczka',
#   'street': '103-795 Eglinton Ave E',
#   'website': None,
#   'city': 'East York',
#   'region': 'ON',
#   'zipcode': 'M4G 4E4',
#   'industry': 'Dentists',
#   'phone': '416-424-3477',
#   'product': None,
#   'description': None},
#  {'business_name': 'Endodontic Specialists',
#   'street': '201-1235 Bay St',
#   'website': 'https://www.yellowpages.ca/gourl/11b78abf35bf7d20f7eceef94a4d9ab7fbd63452?redirect=http%3A%2F%2Fwww.rootcanals.ca%2F',
#   'city': 'Toronto',
#   'region': 'ON',
#   'zipcode': 'M5R 3K4',
#   'industry': 'Dentists',
#   'phone': '416-963-9988',
#   'product': 'Endodontic, Endodontist, Root Canal Specialist',
#   'description': 'At Endodontic Specialists in Toronto, we not only provide expert endodontic services, but we also provide warm and friendly service, that will put you at ease the second you walk t...\nmore...\nSee more text'},
#  {'business_name': 'Yonge Eglinton Periodontics & Implant Surgery',
#   'street': '706-2300 Yonge St',
#   'website': 'https://www.yellowpages.ca/gourl/1f6b8d0e429f8acd4ba4cfd3428e404d281d1e8a?redirect=http%3A%2F%2Fwww.drandrewkay.com%2F',
#   'city': 'Toronto',
#   'region': 'ON',
#   'zipcode': 'M4P 1E4',
#   'industry': 'Dentists',
#   'phone': '416-481-1179',
#   'product': 'Dr Andrew Kay, Periodontal and Dental Implants',
#   'description': 'Located in Toronto, Yonge Eglinton Periodontics & Implant Surgery offers a range of care options for better oral health. Our services include bone grafts, dental implants, extracti...\nmore...\nSee more text'},
#  {'business_name': 'Canadian Orthodontic Partners Ulc',
#   'street': '2200 Yonge St',
#   'website': 'https://www.yellowpages.ca/gourl/ec6a11e0f09d754f3bc4c7d68b843ecb68ca8df1?redirect=http%3A%2F%2Fwww.metaxasortho.ca%2F',
#   'city': 'Toronto',
#   'region': 'ON',
#   'zipcode': 'M4S 2C6',
#   'industry': 'Dentists',
#   'phone': '416-482-4564',
#   'product': 'General Dentist',
#   'description': 'Never underestimate the power of your smile!'},
#  {'business_name': 'Dr Violeta Danciu',
#   'street': '2329 Dundas St W',
#   'website': 'https://www.yellowpages.ca/gourl/82caff302248bdfafe016626db7f9292b379527f?redirect=http%3A%2F%2Fwww.danciudentist.com%2F',
#   'city': 'Toronto',
#   'region': 'ON',
#   'zipcode': 'M6R 1X6',
#   'industry': 'Dentists',
#   'phone': '416-533-4973',
#   'product': None,
#   'description': 'Dr. Violeta Danciu is an experienced Toronto family dentist who provides truly exceptional dental care and satisfaction to for her patients over many years. Contact our clinic today!\nmore...\nSee more text'},
#  {'business_name': 'Dr Marta Prystayko',
#   'street': '305-2425 Bloor St W',
#   'website': 'https://www.yellowpages.ca/gourl/5602e0233f7f0bf47521fbaaa20dde96462ea99f?redirect=http%3A%2F%2Fwww.facebook.com%2F1186411154705330',
#   'city': 'Toronto',
#   'region': 'ON',
#   'zipcode': 'M6S 4W4',
#   'industry': 'Dentists',
#   'phone': '647-484-2943',
#   'product': 'General Dentist, Family Dentist, Cosmetic Services, Root Canal, Dental Implant Consultations, Periodontal Service And Hygiene, Children Dentistry, Teeth Cleaning And Whitening, Sports Mouth Guards',
#   'description': 'Practicing family dentistry in the Bloor West community for over 30 years.'},
#  {'business_name': 'Dr Brian Kotzer',
#   'street': '510-18 King St E',
#   'website': 'https://www.yellowpages.ca/gourl/50082baa114013aaf7978030d75e8d0bed3ef4f7?redirect=http%3A%2F%2Fyongedentalcentre.com%2Findex.php',
#   'city': 'Toronto',
#   'region': 'ON',
#   'zipcode': 'M5C 1C4',
#   'industry': 'Dentists',
#   'phone': '416-367-0212',
#   'product': 'Yonge Dental Centre, Family Dentistry, General & Cosmetic Dentistry',
#   'description': 'Dr. Brian Kotzer   Dr. Paul Wright   Dr. Jennifer Kotzer Dr. Robert Kotzer'},
#  {'business_name': 'Forest Hill Village Orthodontics',
#   'street': '740 Eglinton Ave W',
#   'website': 'https://www.yellowpages.ca/gourl/78286d0dfa3216d6b9445622150ac74ed414feb5?redirect=http%3A%2F%2Fwww.foresthillvillageorthodontics.com%2F',
#   'city': 'Toronto',
#   'region': 'ON',
#   'zipcode': 'M5N 1C4',
#   'industry': 'Dentists',
#   'phone': '416-789-1231',
#   'product': 'ORTHODONTISTS,',
#   'description': "Located in Toronto and Aurora, Ontario, our practice's top priority is to provide you the highest quality orthodontic care in a friendly, comfortable environment\nmore...\nSee more text"},
#  {'business_name': 'Scarlett Road Dentistry',
#   'street': '263 Scarlett Rd',
#   'website': 'https://www.yellowpages.ca/gourl/e70c4c24eaf9fffda2a76ba48391eb0e1c3b4d55?redirect=http%3A%2F%2Fwww.scarlettroaddentistry.com%2F',
#   'city': 'York',
#   'region': 'ON',
#   'zipcode': 'M6N 4L1',
#   'industry': 'Dentists',
#   'phone': '416-763-3773',
#   'product': 'Dr Lorne Levy,',
#   'description': None},
#  {'business_name': 'Dr Paul Wright',
#   'street': '510-18 King St E',
#   'website': 'https://www.yellowpages.ca/gourl/50082baa114013aaf7978030d75e8d0bed3ef4f7?redirect=http%3A%2F%2Fyongedentalcentre.com%2Findex.php',
#   'city': 'Toronto',
#   'region': 'ON',
#   'zipcode': 'M5C 1C4',
#   'industry': 'Dentists',
#   'phone': '416-367-0212',
#   'product': 'Yonge Dental Centre, Dental Care For All Ages',
#   'description': 'Dr. Brian Kotzer   Dr. Paul Wright   Dr. Jennifer Kotzer Dr. Robert Kotzer\nmore...\nSee more text'},
#  {'business_name': 'Dr Jennifer Kotzer',
#   'street': '510-18 King St E',
#   'website': 'https://www.yellowpages.ca/gourl/50082baa114013aaf7978030d75e8d0bed3ef4f7?redirect=http%3A%2F%2Fyongedentalcentre.com%2Findex.php',
#   'city': 'Toronto',
#   'region': 'ON',
#   'zipcode': 'M5C 1C4',
#   'industry': 'Dentists',
#   'phone': '416-367-0212',
#   'product': 'Yonge Dental Centre, Family Dentistry, General & Cosmetic Dentistry',
#   'description': 'Dr. Brian Kotzer   Dr. Paul Wright   Dr. Jennifer Kotzer Dr. Robert Kotzer'},
#  {'business_name': 'Dr Robert Kotzer',
#   'street': '510-18 King St E',
#   'website': 'https://www.yellowpages.ca/gourl/50082baa114013aaf7978030d75e8d0bed3ef4f7?redirect=http%3A%2F%2Fyongedentalcentre.com%2Findex.php',
#   'city': 'Toronto',
#   'region': 'ON',
#   'zipcode': 'M5C 1C4',
#   'industry': 'Dentists',
#   'phone': '416-367-0212',
#   'product': 'Yonge Dental Centre, Dental Care For All Ages',
#   'description': 'Dr. Brian Kotzer   Dr. Paul Wright   Dr. Jennifer Kotzer Dr. Robert Kotzer'},
#  {'business_name': 'Dr Mark Nusinoff',
#   'street': '203-2179 Yonge St',
#   'website': 'https://www.yellowpages.ca/gourl/295951486537e1125e8235a8412a0d672fde46ba?redirect=https%3A%2F%2Fyongestreetdental.com%2F',
#   'city': 'Toronto',
#   'region': 'ON',
#   'zipcode': 'M4S 2B1',
#   'industry': 'Dentists',
#   'phone': '416-488-6633',
#   'product': 'Yonge Street Dental,',
#   'description': None},
#  {'business_name': 'Lombard dental Dr. Kerry Lim',
#   'street': '2 Lombard St',
#   'website': 'https://www.yellowpages.ca/gourl/d06d6e7b7c997a2f872f5d55e69e9dfff411e6d0?redirect=http%3A%2F%2Fwww.drkerrylim.com%2F',
#   'city': 'Toronto',
#   'region': 'ON',
#   'zipcode': 'M5C 1M1',
#   'industry': 'Dentists',
#   'phone': '416-362-3875',
#   'product': 'General Dentist',
#   'description': 'We believe in having winning smiles and healthy teeth that last a lifetime.'},
#  {'business_name': 'Oral Surgery Practice',
#   'street': '340 College St',
#   'website': None,
#   'city': 'Toronto',
#   'region': 'ON',
#   'zipcode': 'M5T 3A9',
#   'industry': 'Dentists',
#   'phone': '416-924-9673',
#   'product': 'oral & maxillofacial surgery',
#   'description': 'For reliable dental care in the downtown Toronto area, visit Oral Surgery Practice on College Street today. Our talented and professional dentists take your well-being into account...\nmore...\nSee more text'},
#  {'business_name': 'Mazzatto Anthony Dr',
#   'street': '65 Queen St W',
#   'website': None,
#   'city': 'Toronto',
#   'region': 'ON',
#   'zipcode': 'M5H 2M5',
#   'industry': 'Dentists',
#   'phone': '416-368-9949',
#   'product': None,
#   'description': 'Dr. Anthony Mazzatto welcomes new patients to his dental office located in downtown Toronto. Offering family dental services, Dr. Mazzatto will be glad to assist you in your way to...\nmore...\nSee more text'}]

# %% [markdown]
# ## Crawl pages

# %%
keyword_dict, place_city_province_dict,pagination_list= parameters()

keyword_list = [key for key, value in keyword_dict.items() if value]
place_city_province_list = [key for key, value in place_city_province_dict.items() if value]
# pagination_list=[key for key, value in pagination_dict.items() if value]
pagination_l=pagination_list

data=[]
for pagination in pagination_l:
    for place_city_province in place_city_province_list:
        for keyword in keyword_list:
            
            # data=[]
            # for i in range(1,len(pagination_list)):
            scraped_data =  parse_listing(keyword,place_city_province,pagination)
            data.append(scraped_data)
            # df = pd.DataFrame(data[i])

            # df_=pd.concat([df, df])
# Out:
# retrieving  https://www.yellowpages.ca/search/si/1/Dentists/toronto+ON
# c:\Users\User\anaconda3\lib\site-packages\urllib3\connectionpool.py:1043: InsecureRequestWarning: Unverified HTTPS request is being made to host 'www.yellowpages.ca'. Adding certificate verification is strongly advised. See: https://urllib3.readthedocs.io/en/1.26.x/advanced-usage.html#ssl-warnings
#   warnings.warn(
# c:\Users\User\anaconda3\lib\site-packages\urllib3\connectionpool.py:1043: InsecureRequestWarning: Unverified HTTPS request is being made to host 'www.yellowpages.ca'. Adding certificate verification is strongly advised. See: https://urllib3.readthedocs.io/en/1.26.x/advanced-usage.html#ssl-warnings
#   warnings.warn(
# retrieving  https://www.yellowpages.ca/search/si/2/Dentists/toronto+ON
# c:\Users\User\anaconda3\lib\site-packages\urllib3\connectionpool.py:1043: InsecureRequestWarning: Unverified HTTPS request is being made to host 'www.yellowpages.ca'. Adding certificate verification is strongly advised. See: https://urllib3.readthedocs.io/en/1.26.x/advanced-usage.html#ssl-warnings
#   warnings.warn(
# c:\Users\User\anaconda3\lib\site-packages\urllib3\connectionpool.py:1043: InsecureRequestWarning: Unverified HTTPS request is being made to host 'www.yellowpages.ca'. Adding certificate verification is strongly advised. See: https://urllib3.readthedocs.io/en/1.26.x/advanced-usage.html#ssl-warnings
#   warnings.warn(
# retrieving  https://www.yellowpages.ca/search/si/3/Dentists/toronto+ON
# c:\Users\User\anaconda3\lib\site-packages\urllib3\connectionpool.py:1043: InsecureRequestWarning: Unverified HTTPS request is being made to host 'www.yellowpages.ca'. Adding certificate verification is strongly advised. See: https://urllib3.readthedocs.io/en/1.26.x/advanced-usage.html#ssl-warnings
#   warnings.warn(
# c:\Users\User\anaconda3\lib\site-packages\urllib3\connectionpool.py:1043: InsecureRequestWarning: Unverified HTTPS request is being made to host 'www.yellowpages.ca'. Adding certificate verification is strongly advised. See: https://urllib3.readthedocs.io/en/1.26.x/advanced-usage.html#ssl-warnings
#   warnings.warn(
# retrieving  https://www.yellowpages.ca/search/si/4/Dentists/toronto+ON
# c:\Users\User\anaconda3\lib\site-packages\urllib3\connectionpool.py:1043: InsecureRequestWarning: Unverified HTTPS request is being made to host 'www.yellowpages.ca'. Adding certificate verification is strongly advised. See: https://urllib3.readthedocs.io/en/1.26.x/advanced-usage.html#ssl-warnings
#   warnings.warn(
# c:\Users\User\anaconda3\lib\site-packages\urllib3\connectionpool.py:1043: InsecureRequestWarning: Unverified HTTPS request is being made to host 'www.yellowpages.ca'. Adding certificate verification is strongly advised. See: https://urllib3.readthedocs.io/en/1.26.x/advanced-usage.html#ssl-warnings
#   warnings.warn(

# %% [markdown]
# ## Create dataframe

# %%
def create_dataframe(list):
    flattened  = [val for sublist in data for val in sublist]
    df=pd.DataFrame(flattened)
    sites=df['website'].tolist()
    sites=df['website'].tolist()
    new = []
    for i in sites:
        try:
            val = i.split("%3A%2F%2F")[-1].split("%")[0]
            new.append(val)
        except Exception:
            val = "null"
            new.append(val)
    df['website']=new
    return df
    
df=create_dataframe(data)

# %%
dfs = []
for i in data:
    dfs.append(pd.DataFrame(i))

mega = pd.concat(dfs)
mega.shape
# Out:
# (116, 10)

# %%
print(mega.duplicated().sum())
# Out:
# 87

# %%
data[0]
# Out:
# [{'business_name': 'AIMS Dentistry at Sheppard',
#   'street': '2048 Sheppard Ave E',
#   'website': 'https://www.yellowpages.ca/gourl/eaeece855862c6db90a46299b8f9505b342a2f5c?redirect=https%3A%2F%2Fdentistryatsheppard.com%2F',
#   'city': 'North York',
#   'region': 'ON',
#   'zipcode': 'M2J 5B3',
#   'industry': 'Dentists',
#   'phone': '647-846-2317',
#   'product': None,
#   'description': 'Dentist'},
#  {'business_name': 'City Oasis Dental',
#   'street': '82 Adelaide St E',
#   'website': 'https://www.yellowpages.ca/gourl/5757443dc0e037ad5f02af9025c59b499e463144?redirect=http%3A%2F%2Fcityoasis.dental%2F',
#   'city': 'Toronto',
#   'region': 'ON',
#   'zipcode': 'M5C 1K9',
#   'industry': 'Dentists',
#   'phone': '647-342-4868',
#   'product': 'General Dentist, Cosmetic Dentist',
#   'description': 'City Oasis Dental strives to provide the highest quality dental care in Toronto in a relaxing & comfortable spa environment. Dental care has never been this comfortable. Call today for an appointment!\nmore...\nSee more text'},
#  {'business_name': 'Pape Dental Centre',
#   'street': '759 Pape Ave',
#   'website': 'https://www.yellowpages.ca/gourl/83db23f52f49541a02de749f6efe3c77d0b7a692?redirect=http%3A%2F%2Fwww.papedental.ca%2F',
#   'city': 'Toronto',
#   'region': 'ON',
#   'zipcode': 'M4K 3T2',
#   'industry': 'Dentists',
#   'phone': '647-558-2829',
#   'product': "Halkiotis Jane Dr, General Dental Practice, General Dentistry, Kid's Dentist, Wide Range Of Dental Services, Family Dentistry, Dentist Office, Dental Care, Dental Clinic, Dental Surgeon, Cosmetic Dentistry",
#   'description': 'Family And Cosmetic Dentistry Serving Toronto Area'},
#  {'business_name': 'Eglinton West Dental',
#   'street': '1114 Eglinton Ave W',
#   'website': 'https://www.yellowpages.ca/gourl/63000c37de3cc60038ab4414c509ae7fc2f59a46?redirect=http%3A%2F%2Feglintonwestdental.ca%2F',
#   'city': 'Toronto',
#   'region': 'ON',
#   'zipcode': 'M6C 2E2',
#   'industry': 'Dentists',
#   'phone': '647-484-2557',
#   'product': None,
#   'description': 'Beautiful smiles are made here ! We offer preventitive, restorative and cosmetic dental services. Gentle Dental Treatment for patients of all ages in Upper Village of Forest Hill.\nmore...\nSee more text'},
#  {'business_name': 'Orthodontics on Danforth',
#   'street': '758 Danforth Ave',
#   'website': 'https://www.yellowpages.ca/gourl/b9699056edeb295e39593e8c2b3ce163807b8e4d?redirect=http%3A%2F%2Fwww.orthodonticsondanforth.com%2F',
#   'city': 'Toronto',
#   'region': 'ON',
#   'zipcode': 'M4J 1L5',
#   'industry': 'Dentists',
#   'phone': '647-559-9324',
#   'product': 'Orthodontist',
#   'description': 'A dental specialist in Orthodontics, providing comprehensive orthodontic care for all ages, in a friendly and family-oriented environment.\nmore...\nSee more text'},
#  {'business_name': 'Strugurescu M Dr',
#   'street': '309-745 Danforth Ave',
#   'website': 'https://www.yellowpages.ca/gourl/8d2066c2cd9b7e59ec922bfa506650687b044e17?redirect=http%3A%2F%2Fwww.danforthdentistry.com%2F',
#   'city': 'Toronto',
#   'region': 'ON',
#   'zipcode': 'M4J 1L4',
#   'industry': 'Dentists',
#   'phone': '416-687-2899',
#   'product': 'General Dentist',
#   'description': 'Dr. Michael Strugurescu focuses on aiding and maintaining complete oral health. He also provides cosmetic dental treatments which can help patients experience the smile they have always wanted.\nmore...\nSee more text'},
#  {'business_name': 'Dr Richard Styka Dentistry Professional Corporation',
#   'street': '1588 Bloor St W',
#   'website': 'https://www.yellowpages.ca/gourl/d6cd13dca9042e80d60290f203e3d79d405b923f?redirect=http%3A%2F%2Fdrstyka.com%2F',
#   'city': 'Toronto',
#   'region': 'ON',
#   'zipcode': 'M6P 1A7',
#   'industry': 'Dentists',
#   'phone': '647-795-9160',
#   'product': 'Family Dentistry',
#   'description': 'Family & Cosmetic Dentistry'},
#  {'business_name': 'Vernon Koo',
#   'street': '1920 Yonge St',
#   'website': 'https://www.yellowpages.ca/gourl/eb61da60f0049fae073149bc6440eed6bc39c7d4?redirect=http%3A%2F%2Fwww.yongedavisvilledentistry.com%2F',
#   'city': 'Toronto',
#   'region': 'ON',
#   'zipcode': 'M4S 3E2',
#   'industry': 'Dentists',
#   'phone': '647-498-0073',
#   'product': 'Periodontists',
#   'description': 'Comprehensive General Practice-New Patients & Emergencies Welcome-Cosmetic Dentistry, Family Dentistry. Located Above Davisville Subway. Entrance From Yonge St. Evening Appointments Available.\nmore...\nSee more text'},
#  {'business_name': 'Dr Steven & Dr Jonathan Stern Dentistry',
#   'street': '2-49 Eglinton Ave E',
#   'website': 'https://www.yellowpages.ca/gourl/6e2aa6da77a3cc992e3e272a6eded1d8a917e2af?redirect=http%3A%2F%2Fdrstern.ca%2F',
#   'city': 'Toronto',
#   'region': 'ON',
#   'zipcode': 'M4P 1G6',
#   'industry': 'Dentists',
#   'phone': '647-846-7243',
#   'product': 'Steven Stern, Community Dentist, General Dentist',
#   'description': 'Don’t let your anxiety about going to the dentist keep you from getting the care you need!'},
#  {'business_name': 'Dentistry on Danforth',
#   'street': '249 Danforth Ave',
#   'website': 'https://www.yellowpages.ca/gourl/7f395eeaa1d349ff12ed3839a3218319ebc1690f?redirect=http%3A%2F%2Fwww.dentistryondanforth.com%2F',
#   'city': 'Toronto',
#   'region': 'ON',
#   'zipcode': 'M4K 1N2',
#   'industry': 'Dentists',
#   'phone': '647-360-3815',
#   'product': 'Dr K Papadopoulos, General And Preventive Dentistry, Dentist, Cleanings, Restorative Dentistry, Implant Dentistry, Cosmetic Dentistry, General Dentist, Community Dentistry, Tooth-Coloured Fillings, Crowns',
#   'description': 'Dentistry on Danforth Provides Comprehensive Dentistry In One Location-Preventive & General Dentistry, Cosmetic, Implant and Restorative Dentistry\nmore...\nSee more text'},
#  {'business_name': 'Royal Bank Plaza Dental Centre',
#   'street': '200 Bay St',
#   'website': 'https://www.yellowpages.ca/gourl/40e5ed1b39e783a7886bf41ccfc5a849da0c11d5?redirect=http%3A%2F%2Fwww.royaldentalcentre.com%2F',
#   'city': 'Toronto',
#   'region': 'ON',
#   'zipcode': 'M5J 2J3',
#   'industry': 'Dentists',
#   'phone': '437-889-3282',
#   'product': None,
#   'description': 'Oral Hygiene/Preventive Care Teeth Whitening  Implants Crown/bridges/veneers Dentures/Extractions Sports Mouth Guards/TMJ night guards Complimentary Cosmetic Consultation Orthodontics & Invisalign\nmore...\nSee more text'},
#  {'business_name': 'Endodontic Specialists',
#   'street': '201-1235 Bay St',
#   'website': 'https://www.yellowpages.ca/gourl/11b78abf35bf7d20f7eceef94a4d9ab7fbd63452?redirect=http%3A%2F%2Fwww.rootcanals.ca%2F',
#   'city': 'Toronto',
#   'region': 'ON',
#   'zipcode': 'M5R 3K4',
#   'industry': 'Dentists',
#   'phone': '416-963-9988',
#   'product': 'Endodontic, Endodontist, Root Canal Specialist',
#   'description': 'At Endodontic Specialists in Toronto, we not only provide expert endodontic services, but we also provide warm and friendly service, that will put you at ease the second you walk t...\nmore...\nSee more text'},
#  {'business_name': 'Dr Paul S Monczka',
#   'street': '103-795 Eglinton Ave E',
#   'website': None,
#   'city': 'East York',
#   'region': 'ON',
#   'zipcode': 'M4G 4E4',
#   'industry': 'Dentists',
#   'phone': '416-424-3477',
#   'product': None,
#   'description': None},
#  {'business_name': 'Canadian Orthodontic Partners Ulc',
#   'street': '2200 Yonge St',
#   'website': 'https://www.yellowpages.ca/gourl/ec6a11e0f09d754f3bc4c7d68b843ecb68ca8df1?redirect=http%3A%2F%2Fwww.metaxasortho.ca%2F',
#   'city': 'Toronto',
#   'region': 'ON',
#   'zipcode': 'M4S 2C6',
#   'industry': 'Dentists',
#   'phone': '416-482-4564',
#   'product': 'General Dentist',
#   'description': 'Never underestimate the power of your smile!'},
#  {'business_name': 'Dr Violeta Danciu',
#   'street': '2329 Dundas St W',
#   'website': 'https://www.yellowpages.ca/gourl/82caff302248bdfafe016626db7f9292b379527f?redirect=http%3A%2F%2Fwww.danciudentist.com%2F',
#   'city': 'Toronto',
#   'region': 'ON',
#   'zipcode': 'M6R 1X6',
#   'industry': 'Dentists',
#   'phone': '416-533-4973',
#   'product': None,
#   'description': 'Dr. Violeta Danciu is an experienced Toronto family dentist who provides truly exceptional dental care and satisfaction to for her patients over many years. Contact our clinic today!\nmore...\nSee more text'},
#  {'business_name': 'Dr Robert Elia',
#   'street': '175 York Mills Rd',
#   'website': 'https://www.yellowpages.ca/gourl/e125d9dcacdb558d51e01037f15896d7560fc8fc?redirect=http%3A%2F%2Fwww.facebook.com%2F760044720798682',
#   'city': 'North York',
#   'region': 'ON',
#   'zipcode': 'M2L 1K6',
#   'industry': 'Dentists',
#   'phone': '416-512-6431',
#   'product': None,
#   'description': 'Dr Elia is proud North York Dentist'},
#  {'business_name': 'Dr Marta Prystayko',
#   'street': '305-2425 Bloor St W',
#   'website': 'https://www.yellowpages.ca/gourl/5602e0233f7f0bf47521fbaaa20dde96462ea99f?redirect=http%3A%2F%2Fwww.facebook.com%2F1186411154705330',
#   'city': 'Toronto',
#   'region': 'ON',
#   'zipcode': 'M6S 4W4',
#   'industry': 'Dentists',
#   'phone': '647-484-2943',
#   'product': 'General Dentist, Family Dentist, Cosmetic Services, Root Canal, Dental Implant Consultations, Periodontal Service And Hygiene, Children Dentistry, Teeth Cleaning And Whitening, Sports Mouth Guards',
#   'description': 'Practicing family dentistry in the Bloor West community for over 30 years.'},
#  {'business_name': 'Yonge Eglinton Periodontics & Implant Surgery',
#   'street': '706-2300 Yonge St',
#   'website': 'https://www.yellowpages.ca/gourl/1f6b8d0e429f8acd4ba4cfd3428e404d281d1e8a?redirect=http%3A%2F%2Fwww.drandrewkay.com%2F',
#   'city': 'Toronto',
#   'region': 'ON',
#   'zipcode': 'M4P 1E4',
#   'industry': 'Dentists',
#   'phone': '416-481-1179',
#   'product': 'Dr Andrew Kay, Periodontal and Dental Implants',
#   'description': 'Located in Toronto, Yonge Eglinton Periodontics & Implant Surgery offers a range of care options for better oral health. Our services include bone grafts, dental implants, extracti...\nmore...\nSee more text'},
#  {'business_name': 'Dagys Arlene P Dr',
#   'street': '340 Kingston Rd',
#   'website': 'https://www.yellowpages.ca/gourl/4a309a7dffa09bcc2aa799f30f525d12e59980b2?redirect=http%3A%2F%2Fwww.facebook.com%2F1701420380146028',
#   'city': 'Toronto',
#   'region': 'ON',
#   'zipcode': 'M4L 1T7',
#   'industry': 'Dentists',
#   'phone': '416-690-8525',
#   'product': None,
#   'description': 'Dagys Arlene P Dr is a Toronto-based dentist. Whether you need a general oral health check-up, or you have a dental emergency, our experienced team can help. Give us a call to arra...\nmore...\nSee more text'},
#  {'business_name': 'Scarlett Road Dentistry',
#   'street': '263 Scarlett Rd',
#   'website': 'https://www.yellowpages.ca/gourl/e70c4c24eaf9fffda2a76ba48391eb0e1c3b4d55?redirect=http%3A%2F%2Fwww.scarlettroaddentistry.com%2F',
#   'city': 'York',
#   'region': 'ON',
#   'zipcode': 'M6N 4L1',
#   'industry': 'Dentists',
#   'phone': '416-763-3773',
#   'product': 'Dr Lorne Levy,',
#   'description': None},
#  {'business_name': 'Dr Mark Nusinoff',
#   'street': '203-2179 Yonge St',
#   'website': 'https://www.yellowpages.ca/gourl/295951486537e1125e8235a8412a0d672fde46ba?redirect=https%3A%2F%2Fyongestreetdental.com%2F',
#   'city': 'Toronto',
#   'region': 'ON',
#   'zipcode': 'M4S 2B1',
#   'industry': 'Dentists',
#   'phone': '416-488-6633',
#   'product': 'Yonge Street Dental,',
#   'description': None},
#  {'business_name': 'Dr Robert Kotzer',
#   'street': '510-18 King St E',
#   'website': 'https://www.yellowpages.ca/gourl/50082baa114013aaf7978030d75e8d0bed3ef4f7?redirect=http%3A%2F%2Fyongedentalcentre.com%2Findex.php',
#   'city': 'Toronto',
#   'region': 'ON',
#   'zipcode': 'M5C 1C4',
#   'industry': 'Dentists',
#   'phone': '416-367-0212',
#   'product': 'Yonge Dental Centre, Dental Care For All Ages',
#   'description': 'Dr. Brian Kotzer   Dr. Paul Wright   Dr. Jennifer Kotzer Dr. Robert Kotzer'},
#  {'business_name': 'Forest Hill Village Orthodontics',
#   'street': '740 Eglinton Ave W',
#   'website': 'https://www.yellowpages.ca/gourl/78286d0dfa3216d6b9445622150ac74ed414feb5?redirect=http%3A%2F%2Fwww.foresthillvillageorthodontics.com%2F',
#   'city': 'Toronto',
#   'region': 'ON',
#   'zipcode': 'M5N 1C4',
#   'industry': 'Dentists',
#   'phone': '416-789-1231',
#   'product': 'ORTHODONTISTS,',
#   'description': "Located in Toronto and Aurora, Ontario, our practice's top priority is to provide you the highest quality orthodontic care in a friendly, comfortable environment\nmore...\nSee more text"},
#  {'business_name': 'Dr Jennifer Kotzer',
#   'street': '510-18 King St E',
#   'website': 'https://www.yellowpages.ca/gourl/50082baa114013aaf7978030d75e8d0bed3ef4f7?redirect=http%3A%2F%2Fyongedentalcentre.com%2Findex.php',
#   'city': 'Toronto',
#   'region': 'ON',
#   'zipcode': 'M5C 1C4',
#   'industry': 'Dentists',
#   'phone': '416-367-0212',
#   'product': 'Yonge Dental Centre, Family Dentistry, General & Cosmetic Dentistry',
#   'description': 'Dr. Brian Kotzer   Dr. Paul Wright   Dr. Jennifer Kotzer Dr. Robert Kotzer'},
#  {'business_name': 'Dr Brian Kotzer',
#   'street': '510-18 King St E',
#   'website': 'https://www.yellowpages.ca/gourl/50082baa114013aaf7978030d75e8d0bed3ef4f7?redirect=http%3A%2F%2Fyongedentalcentre.com%2Findex.php',
#   'city': 'Toronto',
#   'region': 'ON',
#   'zipcode': 'M5C 1C4',
#   'industry': 'Dentists',
#   'phone': '416-367-0212',
#   'product': 'Yonge Dental Centre, Family Dentistry, General & Cosmetic Dentistry',
#   'description': 'Dr. Brian Kotzer   Dr. Paul Wright   Dr. Jennifer Kotzer Dr. Robert Kotzer'},
#  {'business_name': 'Dr Paul Wright',
#   'street': '510-18 King St E',
#   'website': 'https://www.yellowpages.ca/gourl/50082baa114013aaf7978030d75e8d0bed3ef4f7?redirect=http%3A%2F%2Fyongedentalcentre.com%2Findex.php',
#   'city': 'Toronto',
#   'region': 'ON',
#   'zipcode': 'M5C 1C4',
#   'industry': 'Dentists',
#   'phone': '416-367-0212',
#   'product': 'Yonge Dental Centre, Dental Care For All Ages',
#   'description': 'Dr. Brian Kotzer   Dr. Paul Wright   Dr. Jennifer Kotzer Dr. Robert Kotzer\nmore...\nSee more text'},
#  {'business_name': 'Oral Surgery Practice',
#   'street': '340 College St',
#   'website': None,
#   'city': 'Toronto',
#   'region': 'ON',
#   'zipcode': 'M5T 3A9',
#   'industry': 'Dentists',
#   'phone': '416-924-9673',
#   'product': 'oral & maxillofacial surgery',
#   'description': 'For reliable dental care in the downtown Toronto area, visit Oral Surgery Practice on College Street today. Our talented and professional dentists take your well-being into account...\nmore...\nSee more text'},
#  {'business_name': 'Mazzatto Anthony Dr',
#   'street': '65 Queen St W',
#   'website': None,
#   'city': 'Toronto',
#   'region': 'ON',
#   'zipcode': 'M5H 2M5',
#   'industry': 'Dentists',
#   'phone': '416-368-9949',
#   'product': None,
#   'description': 'Dr. Anthony Mazzatto welcomes new patients to his dental office located in downtown Toronto. Offering family dental services, Dr. Mazzatto will be glad to assist you in your way to...\nmore...\nSee more text'},
#  {'business_name': 'Lombard dental Dr. Kerry Lim',
#   'street': '2 Lombard St',
#   'website': 'https://www.yellowpages.ca/gourl/d06d6e7b7c997a2f872f5d55e69e9dfff411e6d0?redirect=http%3A%2F%2Fwww.drkerrylim.com%2F',
#   'city': 'Toronto',
#   'region': 'ON',
#   'zipcode': 'M5C 1M1',
#   'industry': 'Dentists',
#   'phone': '416-362-3875',
#   'product': 'General Dentist',
#   'description': 'We believe in having winning smiles and healthy teeth that last a lifetime.'}]

# %%
df['website'].to_csv('email.csv')

# %% [markdown]
# ## Get emails

# %%
def get_email(url):
    
    unprocessed_urls = deque([url])

    processed_urls = set()

    emails = set()
    url = url

    print("Crawling URL %s" % url)
    response = requests.get(url)

    new_emails = set(re.findall(r"[a-z0-9\.\-+_]+@[a-z0-9\.\-+_]+\.[a-z]+", response.text, re.I))
    new_emails = [mail for mail in new_emails if ".png" not in mail]
    new_emails = [mail for mail in new_emails if ".jpg" not in mail]
    
    emails.update(new_emails)
    
    return emails

# %%
mails = []

for site in df.website.values:
    try:
        mail = get_email("http://" + site)
        
    except Exception:
        try:
            mail = get_email("https://" + site)
        
        except Exception:
            mail = "null"
            pass
    
    mails.append(mail)
# Out:
# Crawling URL http://cityoasis.dental
# Crawling URL http://dentistryatsheppard.com
# Crawling URL http://eglintonwestdental.ca
# Crawling URL http://www.papedental.ca
# Crawling URL http://www.danforthdentistry.com
# Crawling URL http://drstern.ca
# Crawling URL http://www.yongedavisvilledentistry.com
# Crawling URL http://www.dentistryondanforth.com
# Crawling URL http://drstyka.com
# Crawling URL http://www.orthodonticsondanforth.com
# Crawling URL http://www.danciudentist.com
# Crawling URL http://www.royaldentalcentre.com
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# c:\Users\User\Desktop\Projects\Web scraping\Yellowpage original\yellowpages-canada-scraper\yellowpages.ipynb Cell 17' in <cell line: 3>()
#       <a href='vscode-notebook-cell:/c%3A/Users/User/Desktop/Projects/Web%20scraping/Yellowpage%20original/yellowpages-canada-scraper/yellowpages.ipynb#ch0000015?line=2'>3</a> for site in df.website.values:
#       <a href='vscode-notebook-cell:/c%3A/Users/User/Desktop/Projects/Web%20scraping/Yellowpage%20original/yellowpages-canada-scraper/yellowpages.ipynb#ch0000015?line=3'>4</a>     try:
# ----> <a href='vscode-notebook-cell:/c%3A/Users/User/Desktop/Projects/Web%20scraping/Yellowpage%20original/yellowpages-canada-scraper/yellowpages.ipynb#ch0000015?line=4'>5</a>         mail = get_email("http://" + site)
#       <a href='vscode-notebook-cell:/c%3A/Users/User/Desktop/Projects/Web%20scraping/Yellowpage%20original/yellowpages-canada-scraper/yellowpages.ipynb#ch0000015?line=6'>7</a>     except Exception:
#       <a href='vscode-notebook-cell:/c%3A/Users/User/Desktop/Projects/Web%20scraping/Yellowpage%20original/yellowpages-canada-scraper/yellowpages.ipynb#ch0000015?line=7'>8</a>         try:
#
# c:\Users\User\Desktop\Projects\Web scraping\Yellowpage original\yellowpages-canada-scraper\yellowpages.ipynb Cell 16' in get_email(url)
#       <a href='vscode-notebook-cell:/c%3A/Users/User/Desktop/Projects/Web%20scraping/Yellowpage%20original/yellowpages-canada-scraper/yellowpages.ipynb#ch0000014?line=7'>8</a> url = url
#      <a href='vscode-notebook-cell:/c%3A/Users/User/Desktop/Projects/Web%20scraping/Yellowpage%20original/yellowpages-canada-scraper/yellowpages.ipynb#ch0000014?line=9'>10</a> print("Crawling URL %s" % url)
# ---> <a href='vscode-notebook-cell:/c%3A/Users/User/Desktop/Projects/Web%20scraping/Yellowpage%20original/yellowpages-canada-scraper/yellowpages.ipynb#ch0000014?line=10'>11</a> response = requests.get(url)
#      <a href='vscode-notebook-cell:/c%3A/Users/User/Desktop/Projects/Web%20scraping/Yellowpage%20original/yellowpages-canada-scraper/yellowpages.ipynb#ch0000014?line=12'>13</a> new_emails = set(re.findall(r"[a-z0-9\.\-+_]+@[a-z0-9\.\-+_]+\.[a-z]+", response.text, re.I))
#      <a href='vscode-notebook-cell:/c%3A/Users/User/Desktop/Projects/Web%20scraping/Yellowpage%20original/yellowpages-canada-scraper/yellowpages.ipynb#ch0000014?line=13'>14</a> new_emails = [mail for mail in new_emails if ".png" not in mail]
#
# File c:\Users\User\anaconda3\lib\site-packages\requests\api.py:75, in get(url, params, **kwargs)
#      <a href='file:///c%3A/Users/User/anaconda3/lib/site-packages/requests/api.py?line=63'>64</a> def get(url, params=None, **kwargs):
#      <a href='file:///c%3A/Users/User/anaconda3/lib/site-packages/requests/api.py?line=64'>65</a>     r"""Sends a GET request.
#      <a href='file:///c%3A/Users/User/anaconda3/lib/site-packages/requests/api.py?line=65'>66</a>
#      <a href='file:///c%3A/Users/User/anaconda3/lib/site-packages/requests/api.py?line=66'>67</a>     :param url: URL for the new :class:`Request` object.
#    (...)
#      <a href='file:///c%3A/Users/User/anaconda3/lib/site-packages/requests/api.py?line=71'>72</a>     :rtype: requests.Response
#      <a href='file:///c%3A/Users/User/anaconda3/lib/site-packages/requests/api.py?line=72'>73</a>     """
# ---> <a href='file:///c%3A/Users/User/anaconda3/lib/site-packages/requests/api.py?line=74'>75</a>     return request('get', url, params=params, **kwargs)
#
# File c:\Users\User\anaconda3\lib\site-packages\requests\api.py:61, in request(method, url, **kwargs)
#      <a href='file:///c%3A/Users/User/anaconda3/lib/site-packages/requests/api.py?line=56'>57</a> # By using the 'with' statement we are sure the session is closed, thus we
#      <a href='file:///c%3A/Users/User/anaconda3/lib/site-packages/requests/api.py?line=57'>58</a> # avoid leaving sockets open which can trigger a ResourceWarning in some
#      <a href='file:///c%3A/Users/User/anaconda3/lib/site-packages/requests/api.py?line=58'>59</a> # cases, and look like a memory leak in others.
#      <a href='file:///c%3A/Users/User/anaconda3/lib/site-packages/requests/api.py?line=59'>60</a> with sessions.Session() as session:
# ---> <a href='file:///c%3A/Users/User/anaconda3/lib/site-packages/requests/api.py?line=60'>61</a>     return session.request(method=method, url=url, **kwargs)
#
# File c:\Users\User\anaconda3\lib\site-packages\requests\sessions.py:529, in Session.request(self, method, url, params, data, headers, cookies, files, auth, timeout, allow_redirects, proxies, hooks, stream, verify, cert, json)
#     <a href='file:///c%3A/Users/User/anaconda3/lib/site-packages/requests/sessions.py?line=523'>524</a> send_kwargs = {
#     <a href='file:///c%3A/Users/User/anaconda3/lib/site-packages/requests/sessions.py?line=524'>525</a>     'timeout': timeout,
#     <a href='file:///c%3A/Users/User/anaconda3/lib/site-packages/requests/sessions.py?line=525'>526</a>     'allow_redirects': allow_redirects,
#     <a href='file:///c%3A/Users/User/anaconda3/lib/site-packages/requests/sessions.py?line=526'>527</a> }
#     <a href='file:///c%3A/Users/User/anaconda3/lib/site-packages/requests/sessions.py?line=527'>528</a> send_kwargs.update(settings)
# --> <a href='file:///c%3A/Users/User/anaconda3/lib/site-packages/requests/sessions.py?line=528'>529</a> resp = self.send(prep, **send_kwargs)
#     <a href='file:///c%3A/Users/User/anaconda3/lib/site-packages/requests/sessions.py?line=530'>531</a> return resp
#
# File c:\Users\User\anaconda3\lib\site-packages\requests\sessions.py:667, in Session.send(self, request, **kwargs)
#     <a href='file:///c%3A/Users/User/anaconda3/lib/site-packages/requests/sessions.py?line=663'>664</a> if allow_redirects:
#     <a href='file:///c%3A/Users/User/anaconda3/lib/site-packages/requests/sessions.py?line=664'>665</a>     # Redirect resolving generator.
#     <a href='file:///c%3A/Users/User/anaconda3/lib/site-packages/requests/sessions.py?line=665'>666</a>     gen = self.resolve_redirects(r, request, **kwargs)
# --> <a href='file:///c%3A/Users/User/anaconda3/lib/site-packages/requests/sessions.py?line=666'>667</a>     history = [resp for resp in gen]
#     <a href='file:///c%3A/Users/User/anaconda3/lib/site-packages/requests/sessions.py?line=667'>668</a> else:
#     <a href='file:///c%3A/Users/User/anaconda3/lib/site-packages/requests/sessions.py?line=668'>669</a>     history = []
#
# File c:\Users\User\anaconda3\lib\site-packages\requests\sessions.py:667, in <listcomp>(.0)
#     <a href='file:///c%3A/Users/User/anaconda3/lib/site-packages/requests/sessions.py?line=663'>664</a> if allow_redirects:
#     <a href='file:///c%3A/Users/User/anaconda3/lib/site-packages/requests/sessions.py?line=664'>665</a>     # Redirect resolving generator.
#     <a href='file:///c%3A/Users/User/anaconda3/lib/site-packages/requests/sessions.py?line=665'>666</a>     gen = self.resolve_redirects(r, request, **kwargs)
# --> <a href='file:///c%3A/Users/User/anaconda3/lib/site-packages/requests/sessions.py?line=666'>667</a>     history = [resp for resp in gen]
#     <a href='file:///c%3A/Users/User/anaconda3/lib/site-packages/requests/sessions.py?line=667'>668</a> else:
#     <a href='file:///c%3A/Users/User/anaconda3/lib/site-packages/requests/sessions.py?line=668'>669</a>     history = []
#
# File c:\Users\User\anaconda3\lib\site-packages\requests\sessions.py:237, in SessionRedirectMixin.resolve_redirects(self, resp, req, stream, timeout, verify, cert, proxies, yield_requests, **adapter_kwargs)
#     <a href='file:///c%3A/Users/User/anaconda3/lib/site-packages/requests/sessions.py?line=233'>234</a>     yield req
#     <a href='file:///c%3A/Users/User/anaconda3/lib/site-packages/requests/sessions.py?line=234'>235</a> else:
# --> <a href='file:///c%3A/Users/User/anaconda3/lib/site-packages/requests/sessions.py?line=236'>237</a>     resp = self.send(
#     <a href='file:///c%3A/Users/User/anaconda3/lib/site-packages/requests/sessions.py?line=237'>238</a>         req,
#     <a href='file:///c%3A/Users/User/anaconda3/lib/site-packages/requests/sessions.py?line=238'>239</a>         stream=stream,
#     <a href='file:///c%3A/Users/User/anaconda3/lib/site-packages/requests/sessions.py?line=239'>240</a>         timeout=timeout,
#     <a href='file:///c%3A/Users/User/anaconda3/lib/site-packages/requests/sessions.py?line=240'>241</a>         verify=verify,
#     <a href='file:///c%3A/Users/User/anaconda3/lib/site-packages/requests/sessions.py?line=241'>242</a>         cert=cert,
#     <a href='file:///c%3A/Users/User/anaconda3/lib/site-packages/requests/sessions.py?line=242'>243</a>         proxies=proxies,
#     <a href='file:///c%3A/Users/User/anaconda3/lib/site-packages/requests/sessions.py?line=243'>244</a>         allow_redirects=False,
#     <a href='file:///c%3A/Users/User/anaconda3/lib/site-packages/requests/sessions.py?line=244'>245</a>         **adapter_kwargs
#     <a href='file:///c%3A/Users/User/anaconda3/lib/site-packages/requests/sessions.py?line=245'>246</a>     )
#     <a href='file:///c%3A/Users/User/anaconda3/lib/site-packages/requests/sessions.py?line=247'>248</a>     extract_cookies_to_jar(self.cookies, prepared_request, resp.raw)
#     <a href='file:///c%3A/Users/User/anaconda3/lib/site-packages/requests/sessions.py?line=249'>250</a>     # extract redirect url, if any, for the next loop
#
# File c:\Users\User\anaconda3\lib\site-packages\requests\sessions.py:645, in Session.send(self, request, **kwargs)
#     <a href='file:///c%3A/Users/User/anaconda3/lib/site-packages/requests/sessions.py?line=641'>642</a> start = preferred_clock()
#     <a href='file:///c%3A/Users/User/anaconda3/lib/site-packages/requests/sessions.py?line=643'>644</a> # Send the request
# --> <a href='file:///c%3A/Users/User/anaconda3/lib/site-packages/requests/sessions.py?line=644'>645</a> r = adapter.send(request, **kwargs)
#     <a href='file:///c%3A/Users/User/anaconda3/lib/site-packages/requests/sessions.py?line=646'>647</a> # Total elapsed time of the request (approximately)
#     <a href='file:///c%3A/Users/User/anaconda3/lib/site-packages/requests/sessions.py?line=647'>648</a> elapsed = preferred_clock() - start
#
# File c:\Users\User\anaconda3\lib\site-packages\requests\adapters.py:440, in HTTPAdapter.send(self, request, stream, timeout, verify, cert, proxies)
#     <a href='file:///c%3A/Users/User/anaconda3/lib/site-packages/requests/adapters.py?line=437'>438</a> try:
#     <a href='file:///c%3A/Users/User/anaconda3/lib/site-packages/requests/adapters.py?line=438'>439</a>     if not chunked:
# --> <a href='file:///c%3A/Users/User/anaconda3/lib/site-packages/requests/adapters.py?line=439'>440</a>         resp = conn.urlopen(
#     <a href='file:///c%3A/Users/User/anaconda3/lib/site-packages/requests/adapters.py?line=440'>441</a>             method=request.method,
#     <a href='file:///c%3A/Users/User/anaconda3/lib/site-packages/requests/adapters.py?line=441'>442</a>             url=url,
#     <a href='file:///c%3A/Users/User/anaconda3/lib/site-packages/requests/adapters.py?line=442'>443</a>             body=request.body,
#     <a href='file:///c%3A/Users/User/anaconda3/lib/site-packages/requests/adapters.py?line=443'>444</a>             headers=request.headers,
#     <a href='file:///c%3A/Users/User/anaconda3/lib/site-packages/requests/adapters.py?line=444'>445</a>             redirect=False,
#     <a href='file:///c%3A/Users/User/anaconda3/lib/site-packages/requests/adapters.py?line=445'>446</a>             assert_same_host=False,
#     <a href='file:///c%3A/Users/User/anaconda3/lib/site-packages/requests/adapters.py?line=446'>447</a>             preload_content=False,
#     <a href='file:///c%3A/Users/User/anaconda3/lib/site-packages/requests/adapters.py?line=447'>448</a>             decode_content=False,
#     <a href='file:///c%3A/Users/User/anaconda3/lib/site-packages/requests/adapters.py?line=448'>449</a>             retries=self.max_retries,
#     <a href='file:///c%3A/Users/User/anaconda3/lib/site-packages/requests/adapters.py?line=449'>450</a>             timeout=timeout
#     <a href='file:///c%3A/Users/User/anaconda3/lib/site-packages/requests/adapters.py?line=450'>451</a>         )
#     <a href='file:///c%3A/Users/User/anaconda3/lib/site-packages/requests/adapters.py?line=452'>453</a>     # Send the request.
#     <a href='file:///c%3A/Users/User/anaconda3/lib/site-packages/requests/adapters.py?line=453'>454</a>     else:
#     <a href='file:///c%3A/Users/User/anaconda3/lib/site-packages/requests/adapters.py?line=454'>455</a>         if hasattr(conn, 'proxy_pool'):
#
# File c:\Users\User\anaconda3\lib\site-packages\urllib3\connectionpool.py:703, in HTTPConnectionPool.urlopen(self, method, url, body, headers, retries, redirect, assert_same_host, timeout, pool_timeout, release_conn, chunked, body_pos, **response_kw)
#     <a href='file:///c%3A/Users/User/anaconda3/lib/site-packages/urllib3/connectionpool.py?line=699'>700</a>     self._prepare_proxy(conn)
#     <a href='file:///c%3A/Users/User/anaconda3/lib/site-packages/urllib3/connectionpool.py?line=701'>702</a> # Make the request on the httplib connection object.
# --> <a href='file:///c%3A/Users/User/anaconda3/lib/site-packages/urllib3/connectionpool.py?line=702'>703</a> httplib_response = self._make_request(
#     <a href='file:///c%3A/Users/User/anaconda3/lib/site-packages/urllib3/connectionpool.py?line=703'>704</a>     conn,
#     <a href='file:///c%3A/Users/User/anaconda3/lib/site-packages/urllib3/connectionpool.py?line=704'>705</a>     method,
#     <a href='file:///c%3A/Users/User/anaconda3/lib/site-packages/urllib3/connectionpool.py?line=705'>706</a>     url,
#     <a href='file:///c%3A/Users/User/anaconda3/lib/site-packages/urllib3/connectionpool.py?line=706'>707</a>     timeout=timeout_obj,
#     <a href='file:///c%3A/Users/User/anaconda3/lib/site-packages/urllib3/connectionpool.py?line=707'>708</a>     body=body,
#     <a href='file:///c%3A/Users/User/anaconda3/lib/site-packages/urllib3/connectionpool.py?line=708'>709</a>     headers=headers,
#     <a href='file:///c%3A/Users/User/anaconda3/lib/site-packages/urllib3/connectionpool.py?line=709'>710</a>     chunked=chunked,
#     <a href='file:///c%3A/Users/User/anaconda3/lib/site-packages/urllib3/connectionpool.py?line=710'>711</a> )
#     <a href='file:///c%3A/Users/User/anaconda3/lib/site-packages/urllib3/connectionpool.py?line=712'>713</a> # If we're going to release the connection in ``finally:``, then
#     <a href='file:///c%3A/Users/User/anaconda3/lib/site-packages/urllib3/connectionpool.py?line=713'>714</a> # the response doesn't need to know about the connection. Otherwise
#     <a href='file:///c%3A/Users/User/anaconda3/lib/site-packages/urllib3/connectionpool.py?line=714'>715</a> # it will also try to release it and we'll have a double-release
#     <a href='file:///c%3A/Users/User/anaconda3/lib/site-packages/urllib3/connectionpool.py?line=715'>716</a> # mess.
#     <a href='file:///c%3A/Users/User/anaconda3/lib/site-packages/urllib3/connectionpool.py?line=716'>717</a> response_conn = conn if not release_conn else None
#
# File c:\Users\User\anaconda3\lib\site-packages\urllib3\connectionpool.py:449, in HTTPConnectionPool._make_request(self, conn, method, url, timeout, chunked, **httplib_request_kw)
#     <a href='file:///c%3A/Users/User/anaconda3/lib/site-packages/urllib3/connectionpool.py?line=443'>444</a>             httplib_response = conn.getresponse()
#     <a href='file:///c%3A/Users/User/anaconda3/lib/site-packages/urllib3/connectionpool.py?line=444'>445</a>         except BaseException as e:
#     <a href='file:///c%3A/Users/User/anaconda3/lib/site-packages/urllib3/connectionpool.py?line=445'>446</a>             # Remove the TypeError from the exception chain in
#     <a href='file:///c%3A/Users/User/anaconda3/lib/site-packages/urllib3/connectionpool.py?line=446'>447</a>             # Python 3 (including for exceptions like SystemExit).
#     <a href='file:///c%3A/Users/User/anaconda3/lib/site-packages/urllib3/connectionpool.py?line=447'>448</a>             # Otherwise it looks like a bug in the code.
# --> <a href='file:///c%3A/Users/User/anaconda3/lib/site-packages/urllib3/connectionpool.py?line=448'>449</a>             six.raise_from(e, None)
#     <a href='file:///c%3A/Users/User/anaconda3/lib/site-packages/urllib3/connectionpool.py?line=449'>450</a> except (SocketTimeout, BaseSSLError, SocketError) as e:
#     <a href='file:///c%3A/Users/User/anaconda3/lib/site-packages/urllib3/connectionpool.py?line=450'>451</a>     self._raise_timeout(err=e, url=url, timeout_value=read_timeout)
#
# File <string>:3, in raise_from(value, from_value)
#
# File c:\Users\User\anaconda3\lib\site-packages\urllib3\connectionpool.py:444, in HTTPConnectionPool._make_request(self, conn, method, url, timeout, chunked, **httplib_request_kw)
#     <a href='file:///c%3A/Users/User/anaconda3/lib/site-packages/urllib3/connectionpool.py?line=440'>441</a> except TypeError:
#     <a href='file:///c%3A/Users/User/anaconda3/lib/site-packages/urllib3/connectionpool.py?line=441'>442</a>     # Python 3
#     <a href='file:///c%3A/Users/User/anaconda3/lib/site-packages/urllib3/connectionpool.py?line=442'>443</a>     try:
# --> <a href='file:///c%3A/Users/User/anaconda3/lib/site-packages/urllib3/connectionpool.py?line=443'>444</a>         httplib_response = conn.getresponse()
#     <a href='file:///c%3A/Users/User/anaconda3/lib/site-packages/urllib3/connectionpool.py?line=444'>445</a>     except BaseException as e:
#     <a href='file:///c%3A/Users/User/anaconda3/lib/site-packages/urllib3/connectionpool.py?line=445'>446</a>         # Remove the TypeError from the exception chain in
#     <a href='file:///c%3A/Users/User/anaconda3/lib/site-packages/urllib3/connectionpool.py?line=446'>447</a>         # Python 3 (including for exceptions like SystemExit).
#     <a href='file:///c%3A/Users/User/anaconda3/lib/site-packages/urllib3/connectionpool.py?line=447'>448</a>         # Otherwise it looks like a bug in the code.
#     <a href='file:///c%3A/Users/User/anaconda3/lib/site-packages/urllib3/connectionpool.py?line=448'>449</a>         six.raise_from(e, None)
#
# File c:\Users\User\anaconda3\lib\http\client.py:1377, in HTTPConnection.getresponse(self)
#    <a href='file:///c%3A/Users/User/anaconda3/lib/http/client.py?line=1374'>1375</a> try:
#    <a href='file:///c%3A/Users/User/anaconda3/lib/http/client.py?line=1375'>1376</a>     try:
# -> <a href='file:///c%3A/Users/User/anaconda3/lib/http/client.py?line=1376'>1377</a>         response.begin()
#    <a href='file:///c%3A/Users/User/anaconda3/lib/http/client.py?line=1377'>1378</a>     except ConnectionError:
#    <a href='file:///c%3A/Users/User/anaconda3/lib/http/client.py?line=1378'>1379</a>         self.close()
#
# File c:\Users\User\anaconda3\lib\http\client.py:320, in HTTPResponse.begin(self)
#     <a href='file:///c%3A/Users/User/anaconda3/lib/http/client.py?line=317'>318</a> # read until we get a non-100 response
#     <a href='file:///c%3A/Users/User/anaconda3/lib/http/client.py?line=318'>319</a> while True:
# --> <a href='file:///c%3A/Users/User/anaconda3/lib/http/client.py?line=319'>320</a>     version, status, reason = self._read_status()
#     <a href='file:///c%3A/Users/User/anaconda3/lib/http/client.py?line=320'>321</a>     if status != CONTINUE:
#     <a href='file:///c%3A/Users/User/anaconda3/lib/http/client.py?line=321'>322</a>         break
#
# File c:\Users\User\anaconda3\lib\http\client.py:281, in HTTPResponse._read_status(self)
#     <a href='file:///c%3A/Users/User/anaconda3/lib/http/client.py?line=279'>280</a> def _read_status(self):
# --> <a href='file:///c%3A/Users/User/anaconda3/lib/http/client.py?line=280'>281</a>     line = str(self.fp.readline(_MAXLINE + 1), "iso-8859-1")
#     <a href='file:///c%3A/Users/User/anaconda3/lib/http/client.py?line=281'>282</a>     if len(line) > _MAXLINE:
#     <a href='file:///c%3A/Users/User/anaconda3/lib/http/client.py?line=282'>283</a>         raise LineTooLong("status line")
#
# File c:\Users\User\anaconda3\lib\socket.py:704, in SocketIO.readinto(self, b)
#     <a href='file:///c%3A/Users/User/anaconda3/lib/socket.py?line=701'>702</a> while True:
#     <a href='file:///c%3A/Users/User/anaconda3/lib/socket.py?line=702'>703</a>     try:
# --> <a href='file:///c%3A/Users/User/anaconda3/lib/socket.py?line=703'>704</a>         return self._sock.recv_into(b)
#     <a href='file:///c%3A/Users/User/anaconda3/lib/socket.py?line=704'>705</a>     except timeout:
#     <a href='file:///c%3A/Users/User/anaconda3/lib/socket.py?line=705'>706</a>         self._timeout_occurred = True
#
# File c:\Users\User\anaconda3\lib\ssl.py:1241, in SSLSocket.recv_into(self, buffer, nbytes, flags)
#    <a href='file:///c%3A/Users/User/anaconda3/lib/ssl.py?line=1236'>1237</a>     if flags != 0:
#    <a href='file:///c%3A/Users/User/anaconda3/lib/ssl.py?line=1237'>1238</a>         raise ValueError(
#    <a href='file:///c%3A/Users/User/anaconda3/lib/ssl.py?line=1238'>1239</a>           "non-zero flags not allowed in calls to recv_into() on %s" %
#    <a href='file:///c%3A/Users/User/anaconda3/lib/ssl.py?line=1239'>1240</a>           self.__class__)
# -> <a href='file:///c%3A/Users/User/anaconda3/lib/ssl.py?line=1240'>1241</a>     return self.read(nbytes, buffer)
#    <a href='file:///c%3A/Users/User/anaconda3/lib/ssl.py?line=1241'>1242</a> else:
#    <a href='file:///c%3A/Users/User/anaconda3/lib/ssl.py?line=1242'>1243</a>     return super().recv_into(buffer, nbytes, flags)
#
# File c:\Users\User\anaconda3\lib\ssl.py:1099, in SSLSocket.read(self, len, buffer)
#    <a href='file:///c%3A/Users/User/anaconda3/lib/ssl.py?line=1096'>1097</a> try:
#    <a href='file:///c%3A/Users/User/anaconda3/lib/ssl.py?line=1097'>1098</a>     if buffer is not None:
# -> <a href='file:///c%3A/Users/User/anaconda3/lib/ssl.py?line=1098'>1099</a>         return self._sslobj.read(len, buffer)
#    <a href='file:///c%3A/Users/User/anaconda3/lib/ssl.py?line=1099'>1100</a>     else:
#    <a href='file:///c%3A/Users/User/anaconda3/lib/ssl.py?line=1100'>1101</a>         return self._sslobj.read(len)
#
# KeyboardInterrupt:

# %%
df.shape
# Out:
# (261, 10)
